# %% [markdown]
# # Guide on how to use the backtester

# %%
# Ensure the project root is in PATH.
import sys
sys.path.append("../")
# All imports of our code are relative to the project root.

from backtester.backtester import Backtester
from backtester.datamodel import TradingState, OrderDepth, Order, Listing

import numpy as np
import pandas as pd
import sys
import os

# %% [markdown]
# This is the implementation of our trader

# %%
def size_function(z, edge_0, edge_max, max_position = 50):
    z = np.array(z)
    direction = np.where(z > 0, -1, 1)
    abs_z = np.abs(z)
    size = np.where(
        abs_z <= edge_0,
        0,
        np.where(
            abs_z >= edge_max,
            max_position,
            max_position * ((abs_z - edge_0) / (edge_max - edge_0)) ** 2
        )
    )
    return direction * size

def exit_size_function(z, edge_0, edge_max, max_position = 50):
    # Positive quadratic function with points (0, 0) and (-2, 50)
    if z <= 0:
        if z >= -edge_0:
            return 0
        elif z <= -edge_max:
            return max_position
            
        a = -max_position/(edge_max - edge_0)**2
        return a * (z + edge_max)**2 + max_position
    else:
        if z <= edge_0:
            return 0
        elif z >= edge_max:
            return -max_position
        a = max_position/(edge_max - edge_0)**2
        return a * (z-edge_max)**2 - max_position

# %%
class Trader:

    kelp_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    resin_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    squink_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])
    # “If none of the bots trade on an outstanding player quote, the quote is automatically cancelled at the end of the iteration.”

    # I think this might make knowing which curve to move on easier, but what if the spread jumps from -50 to +50? 
    # We will def want to close out. I guess it depends on current position then
    z_ask = ""
    z_bid = ""
    
    def update_df(df, product, state, orders, order_depth):
        buy_orders = sorted(order_depth.buy_orders.items(), key=lambda x: -x[0])
        sell_orders = sorted(order_depth.sell_orders.items(), key=lambda x: x[0])

        bid_levels = buy_orders[:3] + [(None, None)] * (3 - len(buy_orders))
        ask_levels = sell_orders[:3] + [(None, None)] * (3 - len(sell_orders))

        if bid_levels[0][0] is not None and ask_levels[0][0] is not None:
            mid_price = (bid_levels[0][0] + ask_levels[0][0]) / 2
        else:
            mid_price = None

        row = {
            "timestamp": state.timestamp,
            "product": product,
            "bid_price_1": bid_levels[0][0], "bid_volume_1": bid_levels[0][1],
            "bid_price_2": bid_levels[1][0], "bid_volume_2": bid_levels[1][1],
            "bid_price_3": bid_levels[2][0], "bid_volume_3": bid_levels[2][1],
            "ask_price_1": ask_levels[0][0], "ask_volume_1": ask_levels[0][1],
            "ask_price_2": ask_levels[1][0], "ask_volume_2": ask_levels[1][1],
            "ask_price_3": ask_levels[2][0], "ask_volume_3": ask_levels[2][1],
            "mid_price": mid_price,
        }

        df.loc[len(df)] = row



    def run(self, state: TradingState):
        # Only method required. It takes all buy and sell orders for all symbols as an input, and outputs a list of orders to be sent

        result = {}
        synthetic_bid = 0    # What I can sell at
        synthetic_offer = 0    # What I can buy at
        best_ask = 0
        best_bid = 0
        best_ask_jam = 0
        best_bid_jam = 0
        best_bid_croissant = 0
        best_ask_croissant = 0
        available_sell = 0
        available_buy = 0
        print(state.position)
        
        for product in state.order_depths:
            order_depth: OrderDepth = state.order_depths[product]
            orders: List[Order] = []
            # Basket 2 is 4 croissants, 2 jams
            if product == "CROISSANTS":
                if len(order_depth.sell_orders) != 0 and len(order_depth.buy_orders) != 0:
                    best_ask_croissant, best_ask_amount_croissant = list(order_depth.sell_orders.items())[0]
                    best_bid_croissant, best_bid_amount_croissant = list(order_depth.buy_orders.items())[0]
                    synthetic_bid += best_bid_croissant * 4
                    synthetic_offer += best_ask_croissant * 4

            if product == "JAMS":
                if len(order_depth.sell_orders) != 0 and len(order_depth.buy_orders) != 0:
                    best_ask_jam, best_ask_amount_jam = list(order_depth.sell_orders.items())[0]
                    best_bid_jam, best_bid_amount_jam = list(order_depth.buy_orders.items())[0]
                    synthetic_bid += best_bid_jam * 2
                    synthetic_offer += best_ask_jam * 2

            if product == 'PICNIC_BASKET2':
                if len(order_depth.sell_orders) != 0 and len(order_depth.buy_orders) != 0:
                    best_ask, best_ask_amount = list(order_depth.sell_orders.items())[0]
                    best_bid, best_bid_amount = list(order_depth.buy_orders.items())[0]

        available_sell = min(int(best_bid_croissant // 4), int(best_bid_jam // 2))   # How many we can sell synthetica lly
        available_buy = min(int(best_ask_croissant // 4), int(best_ask_jam // 2))    # How many we can buy synthetically

        edge_0 = 40
        edge_max = 100

        edge_max_retreet = 90
        edge_0_retreet = 30

        position_max = int(250/4)

        basket_2_position = state.position.get("PICNIC_BASKET2", 0)
        sell = False
        buy = False
        print(f"BEST ASK: {best_ask}, BEST BID: {best_bid}, Synthetic Bid: {synthetic_bid}, Synthetic Offer: {synthetic_offer}")

        # Redoing entry and exit scheme:
        z_mid = (best_bid + best_ask)/2 - (synthetic_bid + synthetic_offer)/2
        pos_buy = size_function(z_mid, edge_0, edge_max, position_max)
        pos_sell = exit_size_function(z_mid, edge_0_retreet, edge_max_retreet, position_max)

        if z_mid > 0:
            # We only move on the entry curve. Enter more or hold.
           
            if pos_buy <= basket_2_position:
                print("On the entry curve")
                target_position = pos_buy
                trade_needed = int(target_position - basket_2_position)
                trade_multiplier = min(abs(trade_needed), available_sell)
                
                result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_bid, -trade_multiplier)]
                result['JAMS'] = [Order('JAMS', best_ask_jam, 2 * trade_multiplier)]
                result['CROISSANTS'] = [Order('CROISSANTS', best_ask_croissant, 4 * trade_multiplier)]

            else:
                print("Not on entry curve")
                target_position = max(pos_sell, basket_2_position)
                
                trade_needed = int(target_position - basket_2_position)
                trade_multiplier = min(abs(trade_needed), available_sell)
                
                result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_ask, trade_multiplier)]
                result['JAMS'] = [Order('JAMS', best_bid_jam, -2 * trade_multiplier)]
                result['CROISSANTS'] = [Order('CROISSANTS', best_bid_croissant, -4 * trade_multiplier)]
                   
            #print(f"z_mid: {z_mid}, target_position: {target_position}, self_position: {basket_2_position}, trade_needed: {trade_needed}, order: {result}")

        
        elif z_mid < 0:
            if pos_buy >= basket_2_position:
                print("On the entry curve")
                target_position = pos_buy
                trade_needed = int(target_position - basket_2_position)
                trade_multiplier = min(abs(trade_needed), available_sell)
                
                result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_ask, trade_multiplier)]
                result['JAMS'] = [Order('JAMS', best_bid_jam, -2 * trade_multiplier)]
                result['CROISSANTS'] = [Order('CROISSANTS', best_bid_croissant, -4 * trade_multiplier)]

            else:
                print("Not on entry curve")
                target_position = min(pos_sell, basket_2_position)
                
                trade_needed = int(target_position - basket_2_position)
                trade_multiplier = min(abs(trade_needed), available_sell)
                
                result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_bid, -trade_multiplier)]
                result['JAMS'] = [Order('JAMS', best_ask_jam, 2 * trade_multiplier)]
                result['CROISSANTS'] = [Order('CROISSANTS', best_ask_croissant, 4 * trade_multiplier)]
            
            #print(f"z_mid: {z_mid}, target_position: {target_position}, self_position: {basket_2_position}, trade_needed: {trade_needed}, order: {result}")

        '''


        
        # Below should be the sizing scheme. Need to know when to move on which leaf. If z > 0: we are selling, if z < 0: we are buying.
        if best_ask < synthetic_bid:
            z = best_ask - synthetic_bid
            pos_buy = size_function(z, edge_0, edge_max, position_max)
            pos_sell = exit_size_function(z, edge_0_retreet, edge_max_retreet, position_max)
            need_trade = 0
            if pos_buy > basket_2_position:
                target_position = pos_buy
                need_trade = int(target_position - basket_2_position)
            else:
                target_position = min(basket_2_position, pos_sell)
                need_trade = int(target_position - basket_2_position)
            print(f"In A: z = {z}, current_position = {basket_2_position}, targetposition = {target_position}, needed_trade = {need_trade}")
            trade_multiplier = min(abs(need_trade), available_sell)

            
            result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_ask, trade_multiplier)]
            result['JAMS'] = [Order('JAMS', best_bid_jam, -2 * trade_multiplier)]
            result['CROISSANTS'] = [Order('CROISSANTS', best_bid_croissant, -4 * trade_multiplier)]
            buy = True

        elif best_bid > synthetic_offer:
            z = best_bid - synthetic_offer
            pos_buy = size_function(z, edge_0, edge_max, position_max)
            pos_sell = exit_size_function(z, edge_0_retreet, edge_max_retreet, position_max)
            need_trade = 0
            if pos_buy < basket_2_position:
                target_position = pos_buy
                need_trade = int(target_position - basket_2_position)
            else:
                target_position = max(basket_2_position, pos_buy)
                need_trade = int(target_position - basket_2_position)
            print(f"In B: z = {z}, current_position = {basket_2_position}, targetposition = {target_position}, needed_trade = {need_trade}")

            trade_multiplier = min(abs(need_trade), available_buy)

            
            result['PICNIC_BASKET2'] = [Order('PICNIC_BASKET2', best_bid, -trade_multiplier)]
            result['JAMS'] = [Order('JAMS', best_ask_jam, 2 * trade_multiplier)]
            result['CROISSANTS'] = [Order('CROISSANTS', best_ask_croissant, 4 * trade_multiplier)]
            sell = True


        '''
        print(result)

        traderData = "SAMPLE"  # String value holding Trader state data required. It will be delivered as TradingState.traderData on next execution.

        conversions = 1
        return result, conversions, traderData

# %% [markdown]
# Copy paste these below lines whenever you want to access the historical data. These have datatype `pd.Dataframe`.
#
# If you want all 3 days combined into 1, then copy the code for `market_data_all3days` and `trades_all3days`. You can't just `pd.concat()` them all because the backtester doesn't consider day.

# %%
market_data_day_0 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_-1.csv"), sep=";")
market_data_day_neg1 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_0.csv"), sep=";")
market_data_day_neg2 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_1.csv"), sep=";")

trades_day_0 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_-1.csv"), sep=";")
trades_day_neg1 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_0.csv"), sep=";")
trades_day_neg2 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_1.csv"), sep=";")


# concatenates multiple days of historical data into 1.
# drops day column and replaces it with continuous timestamps.
# i.e. day -1 timestamp 0 becomes just timestamp 1,000,000
def concatenate_historical_data(data: list[pd.DataFrame]) -> pd.DataFrame:
    output = data[0]

    for i in range(1, len(data), 1):
        timeshift = output.iloc[-1]["timestamp"] + 100  # 100 for next day
        next_day_copy = data[i].copy()
        next_day_copy["timestamp"] += timeshift

        output = pd.concat([output, next_day_copy])

    return output

market_data_all3days = concatenate_historical_data([market_data_day_neg2, market_data_day_neg1, market_data_day_0])
trades_all3days = concatenate_historical_data([trades_day_neg2, trades_day_neg1, trades_day_0])

# %%
market_data_round_2_day_neg1 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_-1.csv"), sep=";")
market_data_round_2_day_0 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_0.csv"), sep=";")
market_data_round_2_day_1 = pd.read_csv(os.path.join("..", "data", "round2", "prices_round_2_day_1.csv"), sep=";")

trades_round_2_day_neg1 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_-1.csv"), sep=";")
trades_round_2_day_0 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_0.csv"), sep=";")
trades_round_2_day_1 = pd.read_csv(os.path.join("..", "data", "round2", "trades_round_2_day_1.csv"), sep=";")


market_data_round_2_all3days = concatenate_historical_data([market_data_round_2_day_neg1, market_data_round_2_day_0, market_data_round_2_day_1])
trades_round_2_all3days = concatenate_historical_data([trades_round_2_day_neg1, trades_round_2_day_0, trades_round_2_day_1])

# %% [markdown]
# Lets run the backtester

# %%
# 1. Define the listings.
listings = {
    "KELP": Listing(symbol="KELP", product="KELP", denomination="SEASHELLS"),
    "RAINFOREST_RESIN": Listing(symbol="RAINFOREST_RESIN", product="RAINFOREST_RESIN", denomination="SEASHELLS"),
    "SQUID_INK": Listing(symbol="SQUID_INK", product="SQUID_INK", denomination="SEASHELLS"),
    "CROISSANTS": Listing(symbol="CROISSANTS", product="CROISSANTS", denomination="SEASHELLS"),
    "DJEMBES": Listing(symbol="DJEMBES", product="DJEMBES", denomination="SEASHELLS"),
    "JAMS": Listing(symbol="JAMS", product="JAMS", denomination="SEASHELLS"),
    "PICNIC_BASKET1": Listing(symbol="PICNIC_BASKET1", product="PICNIC_BASKET1", denomination="SEASHELLS"),
    "PICNIC_BASKET2": Listing(symbol="PICNIC_BASKET2", product="PICNIC_BASKET2", denomination="SEASHELLS")
}

# 2. Define the position limits.
position_limit = {
    "KELP": 50,
    "RAINFOREST_RESIN": 50,
    "SQUID_INK": 50,
    "CROISSANTS": 250,
    "JAMS": 350,
    "DJEMBES": 60,
    "PICNIC_BASKET1": 60,
    "PICNIC_BASKET2": 100
    
}


# 3. Define fair value evaluation functions. This is used to determine what our PNL is at times throughout execution when our net position is not 0.
def calc_rainforest_resin_fair(order_depth: OrderDepth) -> float:
    return 10000


fair_value_evaluator = {
    # omitting dictionary entries for KELP, SQUID_INK, so that they use default behaviour: fair_price = (best_bid+best_ask)/2
    "RAINFOREST_RESIN": calc_rainforest_resin_fair,
}


# 4. Market data and trade history files.
# These already exist, look at the previous jupyter cell.

# 5. Instantiate trader object
trader = Trader()
bt = Backtester(trader, listings, position_limit, fair_value_evaluator, market_data_round_2_day_1, trades_round_2_day_1, output_log_filename="steven.log")


bt.run()

print(bt.pnl)
# Out:
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 0, 'DJEMBES': 0, 'JAMS': 0, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30258, BEST BID: 30252, Synthetic Bid: 30178, Synthetic Offer: 30190
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30252, -16)], 'JAMS': [(JAMS, 6543, 32)], 'CROISSANTS': [(CROISSANTS, 4276, 64)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 64, 'DJEMBES': 0, 'JAMS': 32, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -12}
# BEST ASK: 30260, BEST BID: 30255, Synthetic Bid: 30182, Synthetic Offer: 30190
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30255, -5)], 'JAMS': [(JAMS, 6543, 10)], 'CROISSANTS': [(CROISSANTS, 4276, 20)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 84, 'DJEMBES': 0, 'JAMS': 42, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -17}
# BEST ASK: 30261, BEST BID: 30256, Synthetic Bid: 30184, Synthetic Offer: 30190
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30256, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4276, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 84, 'DJEMBES': 0, 'JAMS': 42, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -17}
# BEST ASK: 30262, BEST BID: 30256, Synthetic Bid: 30182, Synthetic Offer: 30190
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30256, -1)], 'JAMS': [(JAMS, 6543, 2)], 'CROISSANTS': [(CROISSANTS, 4276, 4)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 88, 'DJEMBES': 0, 'JAMS': 44, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -18}
# BEST ASK: 30261, BEST BID: 30255, Synthetic Bid: 30176, Synthetic Offer: 30184
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30255, -6)], 'JAMS': [(JAMS, 6542, 12)], 'CROISSANTS': [(CROISSANTS, 4275, 24)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 112, 'DJEMBES': 0, 'JAMS': 56, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -24}
# BEST ASK: 30262, BEST BID: 30257, Synthetic Bid: 30178, Synthetic Offer: 30184
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30257, -1)], 'JAMS': [(JAMS, 6542, 2)], 'CROISSANTS': [(CROISSANTS, 4275, 4)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30262, BEST BID: 30256, Synthetic Bid: 30178, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30262, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30256, BEST BID: 30251, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30256, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30256, BEST BID: 30251, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30256, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30254, BEST BID: 30249, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30254, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30261, BEST BID: 30256, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30261, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30257, BEST BID: 30252, Synthetic Bid: 30180, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30257, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30257, BEST BID: 30252, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30257, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30245, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30250, BEST BID: 30244, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30250, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30250, BEST BID: 30244, Synthetic Bid: 30176, Synthetic Offer: 30182
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30250, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30246, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30245, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30250, BEST BID: 30244, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30250, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30243, Synthetic Bid: 30178, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30244, Synthetic Bid: 30178, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30244, Synthetic Bid: 30174, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30243, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30243, BEST BID: 30237, Synthetic Bid: 30176, Synthetic Offer: 30182
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30243, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30241, BEST BID: 30236, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30242, BEST BID: 30237, Synthetic Bid: 30176, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30242, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30243, BEST BID: 30238, Synthetic Bid: 30180, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30243, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30243, BEST BID: 30238, Synthetic Bid: 30180, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30243, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30247, BEST BID: 30241, Synthetic Bid: 30180, Synthetic Offer: 30186
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30247, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30248, BEST BID: 30243, Synthetic Bid: 30180, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30248, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30252, BEST BID: 30247, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30252, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30253, BEST BID: 30250, Synthetic Bid: 30182, Synthetic Offer: 30194
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30253, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30255, BEST BID: 30252, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30255, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30253, BEST BID: 30248, Synthetic Bid: 30182, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30253, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30246, Synthetic Bid: 30182, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30253, BEST BID: 30247, Synthetic Bid: 30184, Synthetic Offer: 30192
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30253, 0)], 'JAMS': [(JAMS, 6544, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30250, BEST BID: 30244, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30250, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30243, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30248, Synthetic Bid: 30182, Synthetic Offer: 30190
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4274, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30246, BEST BID: 30241, Synthetic Bid: 30176, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30246, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30250, BEST BID: 30245, Synthetic Bid: 30176, Synthetic Offer: 30188
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30250, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30249, BEST BID: 30243, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30249, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30248, BEST BID: 30243, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30248, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30245, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30252, BEST BID: 30246, Synthetic Bid: 30176, Synthetic Offer: 30182
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30252, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30252, BEST BID: 30245, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30252, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30251, BEST BID: 30245, Synthetic Bid: 30176, Synthetic Offer: 30184
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30251, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4273, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30246, BEST BID: 30240, Synthetic Bid: 30168, Synthetic Offer: 30176
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30246, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30245, BEST BID: 30240, Synthetic Bid: 30168, Synthetic Offer: 30176
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30245, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30244, BEST BID: 30239, Synthetic Bid: 30168, Synthetic Offer: 30176
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30244, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30243, BEST BID: 30240, Synthetic Bid: 30168, Synthetic Offer: 30176
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30243, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30241, BEST BID: 30235, Synthetic Bid: 30168, Synthetic Offer: 30176
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30234, Synthetic Bid: 30168, Synthetic Offer: 30174
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30241, BEST BID: 30235, Synthetic Bid: 30166, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30242, BEST BID: 30236, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30242, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30234, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30238, BEST BID: 30233, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30238, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30237, BEST BID: 30232, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30234, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30235, BEST BID: 30230, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30235, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30235, BEST BID: 30231, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30235, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30237, BEST BID: 30231, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30231, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30233, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30240, BEST BID: 30235, Synthetic Bid: 30164, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30240, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30238, BEST BID: 30232, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30238, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30230, Synthetic Bid: 30164, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30228, Synthetic Bid: 30164, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30238, BEST BID: 30232, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30238, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30241, BEST BID: 30236, Synthetic Bid: 30166, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30234, Synthetic Bid: 30166, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30237, BEST BID: 30231, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30237, BEST BID: 30231, Synthetic Bid: 30164, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4271, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30235, BEST BID: 30230, Synthetic Bid: 30160, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30235, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30232, Synthetic Bid: 30160, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30227, Synthetic Bid: 30160, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30224, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30232, BEST BID: 30227, Synthetic Bid: 30158, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30232, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30231, BEST BID: 30225, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30231, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30227, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30227, BEST BID: 30222, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30227, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30226, BEST BID: 30220, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30226, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30226, BEST BID: 30220, Synthetic Bid: 30156, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30226, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30225, BEST BID: 30219, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30225, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30226, BEST BID: 30219, Synthetic Bid: 30156, Synthetic Offer: 30162
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30226, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30227, BEST BID: 30221, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30227, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30231, BEST BID: 30226, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30231, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30227, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30227, BEST BID: 30222, Synthetic Bid: 30160, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30227, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30225, BEST BID: 30219, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30225, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30226, BEST BID: 30220, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30226, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30229, BEST BID: 30223, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30229, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30232, BEST BID: 30227, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30232, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30228, BEST BID: 30223, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30228, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30225, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30229, BEST BID: 30224, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30229, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30225, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30227, BEST BID: 30222, Synthetic Bid: 30156, Synthetic Offer: 30162
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30227, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30227, BEST BID: 30222, Synthetic Bid: 30156, Synthetic Offer: 30162
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30227, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30231, BEST BID: 30225, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30231, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30230, BEST BID: 30224, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30228, BEST BID: 30225, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30228, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30227, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30232, BEST BID: 30227, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30232, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30230, Synthetic Bid: 30156, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30234, BEST BID: 30232, Synthetic Bid: 30158, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30234, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30229, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30234, BEST BID: 30228, Synthetic Bid: 30156, Synthetic Offer: 30162
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30234, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30227, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6538, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30237, BEST BID: 30232, Synthetic Bid: 30158, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6539, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30234, BEST BID: 30229, Synthetic Bid: 30160, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30234, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30228, Synthetic Bid: 30160, Synthetic Offer: 30166
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30233, BEST BID: 30228, Synthetic Bid: 30162, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30236, BEST BID: 30231, Synthetic Bid: 30162, Synthetic Offer: 30170
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30233, Synthetic Bid: 30160, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30239, BEST BID: 30234, Synthetic Bid: 30156, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30239, 0)], 'JAMS': [(JAMS, 6540, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 116, 'DJEMBES': 0, 'JAMS': 58, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -25}
# BEST ASK: 30242, BEST BID: 30236, Synthetic Bid: 30156, Synthetic Offer: 30164
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, -1)], 'JAMS': [(JAMS, 6542, 2)], 'CROISSANTS': [(CROISSANTS, 4270, 4)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 120, 'DJEMBES': 0, 'JAMS': 60, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -26}
# BEST ASK: 30246, BEST BID: 30241, Synthetic Bid: 30158, Synthetic Offer: 30164
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, -5)], 'JAMS': [(JAMS, 6542, 10)], 'CROISSANTS': [(CROISSANTS, 4270, 20)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 140, 'DJEMBES': 0, 'JAMS': 70, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -28}
# BEST ASK: 30246, BEST BID: 30241, Synthetic Bid: 30158, Synthetic Offer: 30164
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, -3)], 'JAMS': [(JAMS, 6542, 6)], 'CROISSANTS': [(CROISSANTS, 4270, 12)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30244, BEST BID: 30238, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30244, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30244, BEST BID: 30239, Synthetic Bid: 30158, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30244, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30240, BEST BID: 30235, Synthetic Bid: 30158, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30240, 0)], 'JAMS': [(JAMS, 6541, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30243, BEST BID: 30238, Synthetic Bid: 30160, Synthetic Offer: 30172
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30243, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30241, BEST BID: 30236, Synthetic Bid: 30162, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30241, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30240, BEST BID: 30234, Synthetic Bid: 30162, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30240, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30236, BEST BID: 30231, Synthetic Bid: 30162, Synthetic Offer: 30168
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30230, BEST BID: 30224, Synthetic Bid: 30152, Synthetic Offer: 30160
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30230, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30231, BEST BID: 30226, Synthetic Bid: 30152, Synthetic Offer: 30160
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30231, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30237, BEST BID: 30231, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30237, BEST BID: 30232, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30236, BEST BID: 30231, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30236, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30237, BEST BID: 30231, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30237, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30233, BEST BID: 30228, Synthetic Bid: 30156, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30233, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30232, BEST BID: 30227, Synthetic Bid: 30152, Synthetic Offer: 30162
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30232, 0)], 'JAMS': [(JAMS, 6542, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30232, BEST BID: 30230, Synthetic Bid: 30158, Synthetic Offer: 30164
# Not on entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30232, 0)], 'JAMS': [(JAMS, 6543, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 152, 'DJEMBES': 0, 'JAMS': 76, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': -31}
# BEST ASK: 30231, BEST BID: 30226, Synthetic Bid: 30150, Synthetic Offer: 30162
# Not on entry curve
# ...
# BEST ASK: 30087, BEST BID: 30081, Synthetic Bid: 30104, Synthetic Offer: 30112
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30087, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30088, BEST BID: 30082, Synthetic Bid: 30106, Synthetic Offer: 30114
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30088, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30088, BEST BID: 30083, Synthetic Bid: 30102, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30088, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30089, BEST BID: 30084, Synthetic Bid: 30102, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30089, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30088, BEST BID: 30085, Synthetic Bid: 30102, Synthetic Offer: 30110
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30088, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30093, BEST BID: 30088, Synthetic Bid: 30106, Synthetic Offer: 30114
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30093, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30092, BEST BID: 30086, Synthetic Bid: 30106, Synthetic Offer: 30112
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30092, 0)], 'JAMS': [(JAMS, 6517, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30091, BEST BID: 30085, Synthetic Bid: 30104, Synthetic Offer: 30112
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30091, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30089, BEST BID: 30084, Synthetic Bid: 30104, Synthetic Offer: 30110
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30089, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30086, BEST BID: 30080, Synthetic Bid: 30100, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30086, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30086, BEST BID: 30081, Synthetic Bid: 30100, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30086, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30088, BEST BID: 30083, Synthetic Bid: 30104, Synthetic Offer: 30112
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30088, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30085, BEST BID: 30080, Synthetic Bid: 30100, Synthetic Offer: 30106
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30085, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30082, BEST BID: 30076, Synthetic Bid: 30100, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30082, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30087, BEST BID: 30081, Synthetic Bid: 30100, Synthetic Offer: 30106
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30087, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30087, BEST BID: 30081, Synthetic Bid: 30100, Synthetic Offer: 30108
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30087, 0)], 'JAMS': [(JAMS, 6516, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30094, BEST BID: 30088, Synthetic Bid: 30104, Synthetic Offer: 30114
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30094, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30095, BEST BID: 30093, Synthetic Bid: 30108, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30095, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30099, BEST BID: 30096, Synthetic Bid: 30110, Synthetic Offer: 30118
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30099, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30103, BEST BID: 30098, Synthetic Bid: 30106, Synthetic Offer: 30114
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30103, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30104, BEST BID: 30098, Synthetic Bid: 30106, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30104, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30105, BEST BID: 30099, Synthetic Bid: 30106, Synthetic Offer: 30118
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30105, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4267, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30106, BEST BID: 30100, Synthetic Bid: 30108, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30106, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30108, BEST BID: 30102, Synthetic Bid: 30108, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30108, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30108, BEST BID: 30103, Synthetic Bid: 30108, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30108, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30110, BEST BID: 30104, Synthetic Bid: 30110, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30110, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30110, BEST BID: 30105, Synthetic Bid: 30112, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30110, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30112, BEST BID: 30107, Synthetic Bid: 30108, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30112, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30112, BEST BID: 30106, Synthetic Bid: 30108, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30112, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30113, Synthetic Bid: 30112, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30118, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30113, Synthetic Bid: 30114, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30118, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30113, Synthetic Bid: 30110, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30113, 0)], 'JAMS': [(JAMS, 6520, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30119, BEST BID: 30113, Synthetic Bid: 30112, Synthetic Offer: 30120
# {}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30122, BEST BID: 30116, Synthetic Bid: 30112, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30116, 0)], 'JAMS': [(JAMS, 6520, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30121, BEST BID: 30115, Synthetic Bid: 30114, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30115, 0)], 'JAMS': [(JAMS, 6520, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30113, Synthetic Bid: 30114, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30118, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30115, BEST BID: 30110, Synthetic Bid: 30108, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30115, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30117, BEST BID: 30112, Synthetic Bid: 30112, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30117, 0)], 'JAMS': [(JAMS, 6518, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30120, BEST BID: 30115, Synthetic Bid: 30114, Synthetic Offer: 30120
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30115, 0)], 'JAMS': [(JAMS, 6520, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30113, Synthetic Bid: 30110, Synthetic Offer: 30122
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30118, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30121, BEST BID: 30116, Synthetic Bid: 30114, Synthetic Offer: 30122
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30116, 0)], 'JAMS': [(JAMS, 6521, 0)], 'CROISSANTS': [(CROISSANTS, 4270, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30120, BEST BID: 30115, Synthetic Bid: 30110, Synthetic Offer: 30118
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30115, 0)], 'JAMS': [(JAMS, 6521, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30118, BEST BID: 30112, Synthetic Bid: 30110, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30112, 0)], 'JAMS': [(JAMS, 6520, 0)], 'CROISSANTS': [(CROISSANTS, 4269, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30113, BEST BID: 30111, Synthetic Bid: 30110, Synthetic Offer: 30116
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30113, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30115, BEST BID: 30110, Synthetic Bid: 30110, Synthetic Offer: 30118
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30115, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4268, 0)]}
# {'KELP': 0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0, 'CROISSANTS': 40, 'DJEMBES': 0, 'JAMS': 25, 'PICNIC_BASKET1': 0, 'PICNIC_BASKET2': 0}
# BEST ASK: 30107, BEST BID: 30100, Synthetic Bid: 30102, Synthetic Offer: 30110
# On the entry curve
# {'PICNIC_BASKET2': [(PICNIC_BASKET2, 30107, 0)], 'JAMS': [(JAMS, 6519, 0)], 'CROISSANTS': [(CROISSANTS, 4266, 0)]}
# {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0.0, 'CROISSANTS': -2392.0, 'DJEMBES': 0.0, 'JAMS': 1.0, 'PICNIC_BASKET1': 0.0, 'PICNIC_BASKET2': 6017.0}

# %%
import matplotlib.pyplot as plt    
product = "PICNIC_BASKET2"

resin_metrics = bt.calculate_metrics(product)
print(f"PNL: {bt.pnl}")

print(f"Midpoint Sharpe: {resin_metrics['midpoint_sharpe']:.4f}")
print(f"Spreadcrossing Sharpe: {resin_metrics['spreadcrossing_sharpe']:.4f}")
print(f"Midpoint PnL (bps): {resin_metrics['midpoint_pnl_bps']:.2f}")
print(f"Spreadcrossing PnL (bps): {resin_metrics['spreadcrossing_pnl_bps']:.2f}")

# THIS PART PLOTS SPREADCROSSING_PNL AND MIDPOINT_PNL
spreadcrossing_pnl_history = bt.get_metric("spreadcrossing_pnl", product)
midpoint_pnl_history = bt.get_metric("midpoint_pnl", product)
timestamps = np.unique(bt.market_data["timestamp"])

plt.plot(timestamps, spreadcrossing_pnl_history, label="Spreadcrossing PnL", color="blue")
plt.plot(timestamps, midpoint_pnl_history, label="Midpoint PnL", color="orange")
plt.xlabel("Timestamp")
plt.ylabel("PnL")
plt.title("Spread Crossing vs Midpoint PnL Over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# PNL: {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': 0.0, 'CROISSANTS': -2392.0, 'DJEMBES': 0.0, 'JAMS': 1.0, 'PICNIC_BASKET1': 0.0, 'PICNIC_BASKET2': 6017.0}
# Midpoint Sharpe: 0.1293
# Spreadcrossing Sharpe: 0.1364
# Midpoint PnL (bps): 0.07
# Spreadcrossing PnL (bps): 0.07

# %% [markdown]
# You can copy paste everything, except for the Trader algo, which should be whatever algo you wish to backtest.

# %%
edge_0 = 70
edge_max = 150

edge_max_retreet = 100
edge_0_retreet = 0

position_max = int(250/4)

# %%
pos_sell = exit_size_function(95, edge_0_retreet, edge_max_retreet, position_max)
pos_sell
# Out:
# -61.845

# %%
size_function(133, edge_0, edge_max, position_max)
# Out:
# -38.449687499999996
