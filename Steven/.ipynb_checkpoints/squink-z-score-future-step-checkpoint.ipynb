# %% [markdown]
# # Guide on how to use the backtester

# %%
# Ensure the project root is in PATH.
import sys
sys.path.append("../")
# All imports of our code are relative to the project root.

from backtester.backtester import Backtester
from backtester.datamodel import TradingState, OrderDepth, Order, Listing

import numpy as np
import pandas as pd
import sys
import os

# %% [markdown]
# This is the implementation of our trader

# %%
class Trader:

    kelp_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    resin_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    squink_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])
    # “If none of the bots trade on an outstanding player quote, the quote is automatically cancelled at the end of the iteration.”

    squink_times_buy = []
    squink_times_sell = []

    def update_df(df, product, state, orders, order_depth):
        buy_orders = sorted(order_depth.buy_orders.items(), key=lambda x: -x[0])
        sell_orders = sorted(order_depth.sell_orders.items(), key=lambda x: x[0])

        bid_levels = buy_orders[:3] + [(None, None)] * (3 - len(buy_orders))
        ask_levels = sell_orders[:3] + [(None, None)] * (3 - len(sell_orders))

        if bid_levels[0][0] is not None and ask_levels[0][0] is not None:
            mid_price = (bid_levels[0][0] + ask_levels[0][0]) / 2
        else:
            mid_price = None

        row = {
            "timestamp": state.timestamp,
            "product": product,
            "bid_price_1": bid_levels[0][0], "bid_volume_1": bid_levels[0][1],
            "bid_price_2": bid_levels[1][0], "bid_volume_2": bid_levels[1][1],
            "bid_price_3": bid_levels[2][0], "bid_volume_3": bid_levels[2][1],
            "ask_price_1": ask_levels[0][0], "ask_volume_1": ask_levels[0][1],
            "ask_price_2": ask_levels[1][0], "ask_volume_2": ask_levels[1][1],
            "ask_price_3": ask_levels[2][0], "ask_volume_3": ask_levels[2][1],
            "mid_price": mid_price,
        }

        df.loc[len(df)] = row



    def run(self, state: TradingState):
        # Only method required. It takes all buy and sell orders for all symbols as an input, and outputs a list of orders to be sent

        result = {}
        for product in state.order_depths:
            order_depth: OrderDepth = state.order_depths[product]
            orders: List[Order] = []
            if product == "SQUID_INK":
                # Check the rolling z score. If it is > 4, we sell,
                squink_position = state.position.get(product, 0)
                Trader.update_df(Trader.squink_df, product, state, orders, order_depth) 
                
                if len(order_depth.sell_orders) != 0 and len(order_depth.buy_orders) != 0:
                    best_ask, best_ask_amount = list(order_depth.sell_orders.items())[0]
                    best_bid, best_bid_amount = list(order_depth.buy_orders.items())[0]
                    mid_price = (best_ask + best_bid)/2
                    rolling_window = 150
                    if len(self.squink_df) > rolling_window:
                        z_score = (mid_price - self.squink_df.mid_price.rolling(rolling_window).mean().iloc[-1])/self.squink_df.mid_price.rolling(rolling_window).std().iloc[-1]
                        # Now that I have the Z-Score, I want to buy/sell now and in 20 time steps do the opposite trade.
                        sold_time = False
                        bought_time = False
                        sold_z = False
                        bought_z = False
                        print("Actual Time: ", state.timestamp)
                        print("Exit Time: ", state.timestamp + 20 * 100)

                        if state.timestamp in self.squink_times_sell:
                            orders.append(Order(product, best_ask, -1))
                            bought_time = True
                            
                        if state.timestamp in self.squink_times_buy:
                            orders.append(Order(product, best_bid, 1))
                            sold_time = True
                            
                        if z_score < -2:
                            orders.append(Order(product, best_ask, -1))
                            self.squink_times_buy.append(state.timestamp + 20 * 100)
                            bought_z = True

                        if z_score > 2:
                            orders.append(Order(product, best_bid, 1))
                            self.squink_times_sell.append(state.timestamp + 20 * 100)
                            sold_z = True

                        if (bought_z and sold_time) or (sold_z and bought_time):
                            orders = []

                        
                        



                        
    
                        

                result[product] = orders
                print(orders)

        traderData = "SAMPLE"  # String value holding Trader state data required. It will be delivered as TradingState.traderData on next execution.

        conversions = 1
        return result, conversions, traderData

# %% [markdown]
# Copy paste these below lines whenever you want to access the historical data. These have datatype `pd.Dataframe`.
#
# If you want all 3 days combined into 1, then copy the code for `market_data_all3days` and `trades_all3days`. You can't just `pd.concat()` them all because the backtester doesn't consider day.

# %%
market_data_day_0 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_0.csv"), sep=";")
market_data_day_neg1 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_-1.csv"), sep=";")
market_data_day_neg2 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_-2.csv"), sep=";")

trades_day_0 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_0.csv"), sep=";")
trades_day_neg1 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_-1.csv"), sep=";")
trades_day_neg2 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_-2.csv"), sep=";")


# concatenates multiple days of historical data into 1.
# drops day column and replaces it with continuous timestamps.
# i.e. day -1 timestamp 0 becomes just timestamp 1,000,000
def concatenate_historical_data(data: list[pd.DataFrame]) -> pd.DataFrame:
    output = data[0]

    for i in range(1, len(data), 1):
        timeshift = output.iloc[-1]["timestamp"] + 100  # 100 for next day
        next_day_copy = data[i].copy()
        next_day_copy["timestamp"] += timeshift

        output = pd.concat([output, next_day_copy])

    return output

market_data_all3days = concatenate_historical_data([market_data_day_neg2, market_data_day_neg1, market_data_day_0])
trades_all3days = concatenate_historical_data([trades_day_neg2, trades_day_neg1, trades_day_0])

# %% [markdown]
# Lets run the backtester

# %%
# 1. Define the listings.
listings = {
    "KELP": Listing(symbol="KELP", product="KELP", denomination="SEASHELLS"),
    "RAINFOREST_RESIN": Listing(symbol="RAINFOREST_RESIN", product="RAINFOREST_RESIN", denomination="SEASHELLS"),
    "SQUID_INK": Listing(symbol="SQUID_INK", product="SQUID_INK", denomination="SEASHELLS"),
}

# 2. Define the position limits.
position_limit = {
    "KELP": 50,
    "RAINFOREST_RESIN": 50,
    "SQUID_INK": 50,
}


# 3. Define fair value evaluation functions. This is used to determine what our PNL is at times throughout execution when our net position is not 0.
def calc_rainforest_resin_fair(order_depth: OrderDepth) -> float:
    return 10000


fair_value_evaluator = {
    # omitting dictionary entries for KELP, SQUID_INK, so that they use default behaviour: fair_price = (best_bid+best_ask)/2
    "RAINFOREST_RESIN": calc_rainforest_resin_fair,
}


# 4. Market data and trade history files.
# These already exist, look at the previous jupyter cell.

# 5. Instantiate trader object
trader = Trader()
bt = Backtester(trader, listings, position_limit, fair_value_evaluator, market_data_day_neg2, trades_day_neg2, output_log_filename="steven.log")


bt.run()

print(bt.pnl)
# Out:
# Actual Time:  0
# Exit Time:  2000
# [(SQUID_INK, 1998, 1)]
# Actual Time:  100
# Exit Time:  2100
# [(SQUID_INK, 1999, 1)]
# Actual Time:  200
# Exit Time:  2200
# [(SQUID_INK, 1997, 1)]
# Actual Time:  300
# Exit Time:  2300
# [(SQUID_INK, 1997, 1)]
# Actual Time:  400
# Exit Time:  2400
# [(SQUID_INK, 1996, 1)]
# Actual Time:  500
# Exit Time:  2500
# [(SQUID_INK, 1999, 1)]
# Actual Time:  600
# Exit Time:  2600
# [(SQUID_INK, 1997, 1)]
# Actual Time:  700
# Exit Time:  2700
# [(SQUID_INK, 1999, 1)]
# Actual Time:  800
# Exit Time:  2800
# [(SQUID_INK, 2002, 1)]
# Actual Time:  900
# Exit Time:  2900
# [(SQUID_INK, 1999, 1)]
# Actual Time:  1000
# Exit Time:  3000
# [(SQUID_INK, 1999, 1)]
# Actual Time:  1100
# Exit Time:  3100
# [(SQUID_INK, 1999, 1)]
# Actual Time:  1200
# Exit Time:  3200
# [(SQUID_INK, 1998, 1)]
# Actual Time:  1300
# Exit Time:  3300
# [(SQUID_INK, 1999, 1)]
# Actual Time:  1400
# Exit Time:  3400
# [(SQUID_INK, 1996, 1)]
# Actual Time:  1500
# Exit Time:  3500
# [(SQUID_INK, 1997, 1)]
# Actual Time:  1600
# Exit Time:  3600
# [(SQUID_INK, 1997, 1)]
# Actual Time:  1700
# Exit Time:  3700
# [(SQUID_INK, 1998, 1)]
# Actual Time:  1800
# Exit Time:  3800
# [(SQUID_INK, 1997, 1)]
# Actual Time:  1900
# Exit Time:  3900
# [(SQUID_INK, 2001, 1)]
# Actual Time:  2000
# Exit Time:  4000
# []
# Actual Time:  2100
# Exit Time:  4100
# []
# Actual Time:  2200
# Exit Time:  4200
# []
# Actual Time:  2300
# Exit Time:  4300
# []
# Actual Time:  2400
# Exit Time:  4400
# []
# Actual Time:  2500
# Exit Time:  4500
# []
# Actual Time:  2600
# Exit Time:  4600
# []
# Actual Time:  2700
# Exit Time:  4700
# []
# Actual Time:  2800
# Exit Time:  4800
# []
# Actual Time:  2900
# Exit Time:  4900
# []
# Actual Time:  3000
# Exit Time:  5000
# []
# Actual Time:  3100
# Exit Time:  5100
# [(SQUID_INK, 2003, -1)]
# Actual Time:  3200
# Exit Time:  5200
# [(SQUID_INK, 2002, -1)]
# Actual Time:  3300
# Exit Time:  5300
# [(SQUID_INK, 2002, -1)]
# Actual Time:  3400
# Exit Time:  5400
# [(SQUID_INK, 2003, -1)]
# Actual Time:  3500
# Exit Time:  5500
# [(SQUID_INK, 2002, -1)]
# Actual Time:  3600
# Exit Time:  5600
# [(SQUID_INK, 2004, -1)]
# Actual Time:  3700
# Exit Time:  5700
# [(SQUID_INK, 2003, -1)]
# Actual Time:  3800
# Exit Time:  5800
# [(SQUID_INK, 2004, -1)]
# Actual Time:  3900
# Exit Time:  5900
# [(SQUID_INK, 2001, -1)]
# Actual Time:  4000
# Exit Time:  6000
# [(SQUID_INK, 2003, -1)]
# Actual Time:  4100
# Exit Time:  6100
# [(SQUID_INK, 2001, -1)]
# Actual Time:  4200
# Exit Time:  6200
# [(SQUID_INK, 2002, -1)]
# Actual Time:  4300
# Exit Time:  6300
# [(SQUID_INK, 2002, -1)]
# Actual Time:  4400
# Exit Time:  6400
# [(SQUID_INK, 2000, -1)]
# Actual Time:  4500
# Exit Time:  6500
# [(SQUID_INK, 2001, -1)]
# Actual Time:  4600
# Exit Time:  6600
# [(SQUID_INK, 2002, -1)]
# Actual Time:  4700
# Exit Time:  6700
# [(SQUID_INK, 1999, -1)]
# Actual Time:  4800
# Exit Time:  6800
# [(SQUID_INK, 2001, -1)]
# Actual Time:  4900
# Exit Time:  6900
# [(SQUID_INK, 2000, -1)]
# Actual Time:  5000
# Exit Time:  7000
# [(SQUID_INK, 1998, -1)]
# Actual Time:  5100
# Exit Time:  7100
# []
# Actual Time:  5200
# Exit Time:  7200
# []
# Actual Time:  5300
# Exit Time:  7300
# []
# Actual Time:  5400
# Exit Time:  7400
# []
# Actual Time:  5500
# Exit Time:  7500
# []
# Actual Time:  5600
# Exit Time:  7600
# []
# Actual Time:  5700
# Exit Time:  7700
# []
# Actual Time:  5800
# Exit Time:  7800
# []
# Actual Time:  5900
# Exit Time:  7900
# []
# Actual Time:  6000
# Exit Time:  8000
# []
# Actual Time:  6100
# Exit Time:  8100
# [(SQUID_INK, 1999, -1)]
# Actual Time:  6200
# Exit Time:  8200
# [(SQUID_INK, 1999, -1)]
# Actual Time:  6300
# Exit Time:  8300
# []
# Actual Time:  6400
# Exit Time:  8400
# [(SQUID_INK, 2000, -1)]
# Actual Time:  6500
# Exit Time:  8500
# []
# Actual Time:  6600
# Exit Time:  8600
# []
# Actual Time:  6700
# Exit Time:  8700
# []
# Actual Time:  6800
# Exit Time:  8800
# [(SQUID_INK, 2005, -1)]
# Actual Time:  6900
# Exit Time:  8900
# [(SQUID_INK, 2004, -1)]
# Actual Time:  7000
# Exit Time:  9000
# [(SQUID_INK, 2001, -1)]
# Actual Time:  7100
# Exit Time:  9100
# [(SQUID_INK, 2000, -1)]
# Actual Time:  7200
# Exit Time:  9200
# [(SQUID_INK, 2003, -1)]
# Actual Time:  7300
# Exit Time:  9300
# [(SQUID_INK, 2003, -1)]
# Actual Time:  7400
# Exit Time:  9400
# [(SQUID_INK, 2005, -1)]
# Actual Time:  7500
# Exit Time:  9500
# [(SQUID_INK, 2006, -1)]
# Actual Time:  7600
# Exit Time:  9600
# [(SQUID_INK, 2006, -1)]
# Actual Time:  7700
# Exit Time:  9700
# []
# Actual Time:  7800
# Exit Time:  9800
# []
# Actual Time:  7900
# Exit Time:  9900
# [(SQUID_INK, 2007, -1)]
# Actual Time:  8000
# Exit Time:  10000
# [(SQUID_INK, 2006, -1)]
# Actual Time:  8100
# Exit Time:  10100
# [(SQUID_INK, 2005, -1)]
# Actual Time:  8200
# Exit Time:  10200
# [(SQUID_INK, 2004, -1)]
# Actual Time:  8300
# Exit Time:  10300
# [(SQUID_INK, 2004, -1)]
# Actual Time:  8400
# Exit Time:  10400
# [(SQUID_INK, 2005, -1)]
# Actual Time:  8500
# Exit Time:  10500
# [(SQUID_INK, 2003, -1)]
# Actual Time:  8600
# Exit Time:  10600
# [(SQUID_INK, 2006, -1)]
# Actual Time:  8700
# Exit Time:  10700
# [(SQUID_INK, 2006, -1)]
# Actual Time:  8800
# Exit Time:  10800
# [(SQUID_INK, 2005, -1)]
# Actual Time:  8900
# Exit Time:  10900
# [(SQUID_INK, 2005, -1)]
# Actual Time:  9000
# Exit Time:  11000
# [(SQUID_INK, 2004, -1)]
# Actual Time:  9100
# Exit Time:  11100
# [(SQUID_INK, 2006, -1)]
# Actual Time:  9200
# Exit Time:  11200
# [(SQUID_INK, 2005, -1)]
# Actual Time:  9300
# Exit Time:  11300
# [(SQUID_INK, 2006, -1)]
# Actual Time:  9400
# Exit Time:  11400
# [(SQUID_INK, 2004, -1)]
# Actual Time:  9500
# Exit Time:  11500
# [(SQUID_INK, 2004, -1)]
# Actual Time:  9600
# Exit Time:  11600
# []
# Actual Time:  9700
# Exit Time:  11700
# []
# Actual Time:  9800
# Exit Time:  11800
# []
# Actual Time:  9900
# Exit Time:  11900
# []
# Actual Time:  10000
# Exit Time:  12000
# []
# Actual Time:  10100
# Exit Time:  12100
# []
# Actual Time:  10200
# Exit Time:  12200
# []
# Actual Time:  10300
# Exit Time:  12300
# []
# Actual Time:  10400
# Exit Time:  12400
# []
# Actual Time:  10500
# Exit Time:  12500
# []
# Actual Time:  10600
# Exit Time:  12600
# []
# Actual Time:  10700
# Exit Time:  12700
# []
# Actual Time:  10800
# Exit Time:  12800
# []
# Actual Time:  10900
# Exit Time:  12900
# []
# Actual Time:  11000
# Exit Time:  13000
# []
# Actual Time:  11100
# Exit Time:  13100
# []
# Actual Time:  11200
# Exit Time:  13200
# []
# Actual Time:  11300
# Exit Time:  13300
# []
# Actual Time:  11400
# Exit Time:  13400
# [(SQUID_INK, 2006, -1)]
# Actual Time:  11500
# Exit Time:  13500
# [(SQUID_INK, 2006, -1)]
# Actual Time:  11600
# Exit Time:  13600
# [(SQUID_INK, 2005, -1)]
# Actual Time:  11700
# Exit Time:  13700
# []
# Actual Time:  11800
# Exit Time:  13800
# []
# Actual Time:  11900
# Exit Time:  13900
# []
# Actual Time:  12000
# Exit Time:  14000
# []
# Actual Time:  12100
# Exit Time:  14100
# [(SQUID_INK, 2006, -1)]
# Actual Time:  12200
# Exit Time:  14200
# []
# Actual Time:  12300
# Exit Time:  14300
# []
# Actual Time:  12400
# Exit Time:  14400
# []
# Actual Time:  12500
# Exit Time:  14500
# []
# Actual Time:  12600
# Exit Time:  14600
# []
# Actual Time:  12700
# Exit Time:  14700
# []
# Actual Time:  12800
# Exit Time:  14800
# []
# Actual Time:  12900
# Exit Time:  14900
# []
# Actual Time:  13000
# Exit Time:  15000
# []
# Actual Time:  13100
# Exit Time:  15100
# []
# Actual Time:  13200
# Exit Time:  15200
# []
# Actual Time:  13300
# Exit Time:  15300
# []
# Actual Time:  13400
# Exit Time:  15400
# []
# Actual Time:  13500
# Exit Time:  15500
# []
# Actual Time:  13600
# Exit Time:  15600
# []
# Actual Time:  13700
# Exit Time:  15700
# []
# Actual Time:  13800
# Exit Time:  15800
# []
# Actual Time:  13900
# Exit Time:  15900
# []
# Actual Time:  14000
# Exit Time:  16000
# []
# Actual Time:  14100
# Exit Time:  16100
# []
# Actual Time:  14200
# Exit Time:  16200
# []
# Actual Time:  14300
# Exit Time:  16300
# []
# Actual Time:  14400
# Exit Time:  16400
# []
# Actual Time:  14500
# Exit Time:  16500
# []
# Actual Time:  14600
# Exit Time:  16600
# []
# Actual Time:  14700
# Exit Time:  16700
# []
# Actual Time:  14800
# Exit Time:  16800
# []
# Actual Time:  14900
# Exit Time:  16900
# []
# Actual Time:  15000
# Exit Time:  17000
# []
# Actual Time:  15100
# Exit Time:  17100
# []
# Actual Time:  15200
# Exit Time:  17200
# []
# Actual Time:  15300
# Exit Time:  17300
# []
# Actual Time:  15400
# Exit Time:  17400
# []
# Actual Time:  15500
# Exit Time:  17500
# []
# Actual Time:  15600
# Exit Time:  17600
# []
# Actual Time:  15700
# Exit Time:  17700
# []
# Actual Time:  15800
# Exit Time:  17800
# []
# Actual Time:  15900
# Exit Time:  17900
# []
# Actual Time:  16000
# Exit Time:  18000
# []
# Actual Time:  16100
# Exit Time:  18100
# []
# Actual Time:  16200
# Exit Time:  18200
# []
# Actual Time:  16300
# Exit Time:  18300
# []
# Actual Time:  16400
# Exit Time:  18400
# [(SQUID_INK, 1995, -1)]
# Actual Time:  16500
# Exit Time:  18500
# []
# Actual Time:  16600
# Exit Time:  18600
# []
# Actual Time:  16700
# Exit Time:  18700
# []
# Actual Time:  16800
# Exit Time:  18800
# []
# Actual Time:  16900
# Exit Time:  18900
# []
# Actual Time:  17000
# Exit Time:  19000
# [(SQUID_INK, 1997, -1)]
# Actual Time:  17100
# Exit Time:  19100
# []
# Actual Time:  17200
# Exit Time:  19200
# []
# Actual Time:  17300
# Exit Time:  19300
# [(SQUID_INK, 1995, 1)]
# Actual Time:  17400
# Exit Time:  19400
# []
# Actual Time:  17500
# Exit Time:  19500
# [(SQUID_INK, 1996, 1)]
# Actual Time:  17600
# Exit Time:  19600
# [(SQUID_INK, 1994, 1)]
# Actual Time:  17700
# Exit Time:  19700
# [(SQUID_INK, 1994, 1)]
# Actual Time:  17800
# Exit Time:  19800
# [(SQUID_INK, 1995, 1)]
# Actual Time:  17900
# Exit Time:  19900
# [(SQUID_INK, 1994, 1)]
# Actual Time:  18000
# Exit Time:  20000
# [(SQUID_INK, 1995, 1)]
# Actual Time:  18100
# Exit Time:  20100
# []
# Actual Time:  18200
# Exit Time:  20200
# []
# Actual Time:  18300
# Exit Time:  20300
# []
# Actual Time:  18400
# Exit Time:  20400
# [(SQUID_INK, 1993, 1)]
# Actual Time:  18500
# Exit Time:  20500
# []
# Actual Time:  18600
# Exit Time:  20600
# []
# Actual Time:  18700
# Exit Time:  20700
# []
# Actual Time:  18800
# Exit Time:  20800
# []
# Actual Time:  18900
# Exit Time:  20900
# []
# Actual Time:  19000
# Exit Time:  21000
# [(SQUID_INK, 1995, 1)]
# Actual Time:  19100
# Exit Time:  21100
# []
# Actual Time:  19200
# Exit Time:  21200
# []
# Actual Time:  19300
# Exit Time:  21300
# []
# Actual Time:  19400
# Exit Time:  21400
# []
# Actual Time:  19500
# Exit Time:  21500
# []
# Actual Time:  19600
# Exit Time:  21600
# []
# Actual Time:  19700
# Exit Time:  21700
# []
# Actual Time:  19800
# Exit Time:  21800
# []
# Actual Time:  19900
# Exit Time:  21900
# []
# Actual Time:  20000
# Exit Time:  22000
# []
# Actual Time:  20100
# Exit Time:  22100
# []
# Actual Time:  20200
# Exit Time:  22200
# []
# Actual Time:  20300
# Exit Time:  22300
# []
# Actual Time:  20400
# Exit Time:  22400
# []
# Actual Time:  20500
# Exit Time:  22500
# []
# Actual Time:  20600
# Exit Time:  22600
# []
# Actual Time:  20700
# Exit Time:  22700
# []
# Actual Time:  20800
# Exit Time:  22800
# []
# Actual Time:  20900
# Exit Time:  22900
# []
# Actual Time:  21000
# Exit Time:  23000
# []
# Actual Time:  21100
# Exit Time:  23100
# []
# Actual Time:  21200
# Exit Time:  23200
# []
# Actual Time:  21300
# Exit Time:  23300
# []
# Actual Time:  21400
# Exit Time:  23400
# []
# Actual Time:  21500
# Exit Time:  23500
# []
# Actual Time:  21600
# Exit Time:  23600
# []
# Actual Time:  21700
# Exit Time:  23700
# []
# Actual Time:  21800
# Exit Time:  23800
# []
# Actual Time:  21900
# Exit Time:  23900
# []
# Actual Time:  22000
# Exit Time:  24000
# []
# Actual Time:  22100
# Exit Time:  24100
# []
# Actual Time:  22200
# Exit Time:  24200
# []
# Actual Time:  22300
# Exit Time:  24300
# []
# Actual Time:  22400
# Exit Time:  24400
# []
# Actual Time:  22500
# Exit Time:  24500
# []
# Actual Time:  22600
# Exit Time:  24600
# []
# Actual Time:  22700
# Exit Time:  24700
# []
# Actual Time:  22800
# Exit Time:  24800
# []
# Actual Time:  22900
# Exit Time:  24900
# []
# Actual Time:  23000
# Exit Time:  25000
# []
# Actual Time:  23100
# Exit Time:  25100
# []
# Actual Time:  23200
# Exit Time:  25200
# []
# Actual Time:  23300
# Exit Time:  25300
# []
# Actual Time:  23400
# Exit Time:  25400
# []
# Actual Time:  23500
# Exit Time:  25500
# []
# Actual Time:  23600
# Exit Time:  25600
# []
# Actual Time:  23700
# Exit Time:  25700
# []
# Actual Time:  23800
# Exit Time:  25800
# []
# Actual Time:  23900
# Exit Time:  25900
# []
# Actual Time:  24000
# Exit Time:  26000
# []
# Actual Time:  24100
# Exit Time:  26100
# []
# Actual Time:  24200
# Exit Time:  26200
# []
# Actual Time:  24300
# Exit Time:  26300
# []
# Actual Time:  24400
# Exit Time:  26400
# []
# Actual Time:  24500
# Exit Time:  26500
# []
# Actual Time:  24600
# Exit Time:  26600
# []
# Actual Time:  24700
# Exit Time:  26700
# []
# Actual Time:  24800
# Exit Time:  26800
# []
# Actual Time:  24900
# Exit Time:  26900
# []
# Actual Time:  25000
# Exit Time:  27000
# []
# Actual Time:  25100
# Exit Time:  27100
# []
# Actual Time:  25200
# Exit Time:  27200
# []
# Actual Time:  25300
# Exit Time:  27300
# []
# Actual Time:  25400
# Exit Time:  27400
# []
# Actual Time:  25500
# Exit Time:  27500
# []
# Actual Time:  25600
# Exit Time:  27600
# []
# Actual Time:  25700
# Exit Time:  27700
# []
# Actual Time:  25800
# Exit Time:  27800
# []
# Actual Time:  25900
# Exit Time:  27900
# []
# Actual Time:  26000
# Exit Time:  28000
# []
# Actual Time:  26100
# Exit Time:  28100
# []
# Actual Time:  26200
# Exit Time:  28200
# []
# Actual Time:  26300
# Exit Time:  28300
# []
# Actual Time:  26400
# Exit Time:  28400
# []
# Actual Time:  26500
# Exit Time:  28500
# []
# Actual Time:  26600
# Exit Time:  28600
# []
# Actual Time:  26700
# Exit Time:  28700
# []
# Actual Time:  26800
# Exit Time:  28800
# []
# Actual Time:  26900
# Exit Time:  28900
# []
# Actual Time:  27000
# Exit Time:  29000
# []
# Actual Time:  27100
# Exit Time:  29100
# []
# Actual Time:  27200
# Exit Time:  29200
# []
# Actual Time:  27300
# Exit Time:  29300
# []
# Actual Time:  27400
# Exit Time:  29400
# []
# Actual Time:  27500
# Exit Time:  29500
# []
# Actual Time:  27600
# Exit Time:  29600
# []
# Actual Time:  27700
# Exit Time:  29700
# []
# Actual Time:  27800
# Exit Time:  29800
# []
# Actual Time:  27900
# Exit Time:  29900
# []
# Actual Time:  28000
# Exit Time:  30000
# []
# Actual Time:  28100
# Exit Time:  30100
# []
# Actual Time:  28200
# Exit Time:  30200
# []
# Actual Time:  28300
# Exit Time:  30300
# []
# Actual Time:  28400
# Exit Time:  30400
# []
# Actual Time:  28500
# Exit Time:  30500
# []
# Actual Time:  28600
# Exit Time:  30600
# []
# Actual Time:  28700
# Exit Time:  30700
# []
# Actual Time:  28800
# Exit Time:  30800
# []
# Actual Time:  28900
# Exit Time:  30900
# []
# Actual Time:  29000
# Exit Time:  31000
# []
# Actual Time:  29100
# Exit Time:  31100
# []
# Actual Time:  29200
# Exit Time:  31200
# []
# Actual Time:  29300
# Exit Time:  31300
# []
# Actual Time:  29400
# Exit Time:  31400
# []
# Actual Time:  29500
# Exit Time:  31500
# []
# Actual Time:  29600
# Exit Time:  31600
# []
# Actual Time:  29700
# Exit Time:  31700
# []
# Actual Time:  29800
# Exit Time:  31800
# [(SQUID_INK, 1992, -1)]
# Actual Time:  29900
# Exit Time:  31900
# [(SQUID_INK, 1991, -1)]
# Actual Time:  30000
# Exit Time:  32000
# [(SQUID_INK, 1990, -1)]
# Actual Time:  30100
# Exit Time:  32100
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30200
# Exit Time:  32200
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30300
# Exit Time:  32300
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30400
# Exit Time:  32400
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30500
# Exit Time:  32500
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30600
# Exit Time:  32600
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30700
# Exit Time:  32700
# [(SQUID_INK, 1989, -1)]
# Actual Time:  30800
# Exit Time:  32800
# [(SQUID_INK, 1988, -1)]
# Actual Time:  30900
# Exit Time:  32900
# [(SQUID_INK, 1987, -1)]
# Actual Time:  31000
# Exit Time:  33000
# [(SQUID_INK, 1986, -1)]
# Actual Time:  31100
# Exit Time:  33100
# [(SQUID_INK, 1987, -1)]
# Actual Time:  31200
# Exit Time:  33200
# [(SQUID_INK, 1985, -1), (SQUID_INK, 1985, -1)]
# Actual Time:  31300
# Exit Time:  33300
# [(SQUID_INK, 1985, -1)]
# Actual Time:  31400
# Exit Time:  33400
# [(SQUID_INK, 1986, -1)]
# Actual Time:  31500
# Exit Time:  33500
# [(SQUID_INK, 1986, -1)]
# Actual Time:  31600
# Exit Time:  33600
# [(SQUID_INK, 1986, -1)]
# Actual Time:  31700
# Exit Time:  33700
# [(SQUID_INK, 1985, -1), (SQUID_INK, 1985, -1)]
# Actual Time:  31800
# Exit Time:  33800
# []
# Actual Time:  31900
# Exit Time:  33900
# []
# Actual Time:  32000
# Exit Time:  34000
# [(SQUID_INK, 1986, 1)]
# Actual Time:  32100
# Exit Time:  34100
# [(SQUID_INK, 1986, 1)]
# Actual Time:  32200
# Exit Time:  34200
# [(SQUID_INK, 1986, 1)]
# Actual Time:  32300
# Exit Time:  34300
# [(SQUID_INK, 1988, 1)]
# Actual Time:  32400
# Exit Time:  34400
# [(SQUID_INK, 1987, 1)]
# Actual Time:  32500
# Exit Time:  34500
# [(SQUID_INK, 1989, 1)]
# Actual Time:  32600
# Exit Time:  34600
# [(SQUID_INK, 1989, 1)]
# Actual Time:  32700
# Exit Time:  34700
# [(SQUID_INK, 1992, 1)]
# Actual Time:  32800
# Exit Time:  34800
# [(SQUID_INK, 1989, 1)]
# Actual Time:  32900
# Exit Time:  34900
# [(SQUID_INK, 1989, 1)]
# Actual Time:  33000
# Exit Time:  35000
# [(SQUID_INK, 1990, 1)]
# Actual Time:  33100
# Exit Time:  35100
# [(SQUID_INK, 1991, 1)]
# Actual Time:  33200
# Exit Time:  35200
# [(SQUID_INK, 1991, 1)]
# Actual Time:  33300
# Exit Time:  35300
# [(SQUID_INK, 1990, 1)]
# Actual Time:  33400
# Exit Time:  35400
# [(SQUID_INK, 1990, 1)]
# Actual Time:  33500
# Exit Time:  35500
# [(SQUID_INK, 1990, 1)]
# Actual Time:  33600
# Exit Time:  35600
# [(SQUID_INK, 1990, 1)]
# Actual Time:  33700
# Exit Time:  35700
# [(SQUID_INK, 1991, 1)]
# Actual Time:  33800
# Exit Time:  35800
# [(SQUID_INK, 1993, 1)]
# Actual Time:  33900
# Exit Time:  35900
# [(SQUID_INK, 1995, 1)]
# Actual Time:  34000
# Exit Time:  36000
# []
# Actual Time:  34100
# Exit Time:  36100
# []
# Actual Time:  34200
# Exit Time:  36200
# []
# Actual Time:  34300
# Exit Time:  36300
# []
# Actual Time:  34400
# Exit Time:  36400
# []
# Actual Time:  34500
# Exit Time:  36500
# []
# Actual Time:  34600
# Exit Time:  36600
# []
# Actual Time:  34700
# Exit Time:  36700
# []
# Actual Time:  34800
# Exit Time:  36800
# []
# Actual Time:  34900
# Exit Time:  36900
# []
# Actual Time:  35000
# Exit Time:  37000
# []
# Actual Time:  35100
# Exit Time:  37100
# []
# Actual Time:  35200
# Exit Time:  37200
# []
# Actual Time:  35300
# Exit Time:  37300
# []
# Actual Time:  35400
# Exit Time:  37400
# []
# Actual Time:  35500
# Exit Time:  37500
# []
# Actual Time:  35600
# Exit Time:  37600
# []
# Actual Time:  35700
# Exit Time:  37700
# []
# Actual Time:  35800
# Exit Time:  37800
# []
# Actual Time:  35900
# Exit Time:  37900
# []
# Actual Time:  36000
# Exit Time:  38000
# []
# Actual Time:  36100
# Exit Time:  38100
# []
# Actual Time:  36200
# Exit Time:  38200
# [(SQUID_INK, 1990, 1)]
# Actual Time:  36300
# Exit Time:  38300
# [(SQUID_INK, 1989, 1)]
# Actual Time:  36400
# Exit Time:  38400
# [(SQUID_INK, 1991, 1)]
# Actual Time:  36500
# Exit Time:  38500
# [(SQUID_INK, 1991, 1)]
# Actual Time:  36600
# Exit Time:  38600
# [(SQUID_INK, 1991, 1)]
# Actual Time:  36700
# Exit Time:  38700
# [(SQUID_INK, 1991, 1)]
# Actual Time:  36800
# Exit Time:  38800
# [(SQUID_INK, 1991, 1)]
# Actual Time:  36900
# Exit Time:  38900
# [(SQUID_INK, 1989, 1)]
# Actual Time:  37000
# Exit Time:  39000
# []
# Actual Time:  37100
# Exit Time:  39100
# [(SQUID_INK, 1989, 1)]
# Actual Time:  37200
# Exit Time:  39200
# [(SQUID_INK, 1990, 1)]
# Actual Time:  37300
# Exit Time:  39300
# [(SQUID_INK, 1990, 1)]
# Actual Time:  37400
# Exit Time:  39400
# []
# Actual Time:  37500
# Exit Time:  39500
# []
# Actual Time:  37600
# Exit Time:  39600
# []
# Actual Time:  37700
# Exit Time:  39700
# []
# Actual Time:  37800
# Exit Time:  39800
# []
# Actual Time:  37900
# Exit Time:  39900
# []
# Actual Time:  38000
# Exit Time:  40000
# []
# Actual Time:  38100
# Exit Time:  40100
# []
# Actual Time:  38200
# Exit Time:  40200
# []
# Actual Time:  38300
# Exit Time:  40300
# []
# Actual Time:  38400
# Exit Time:  40400
# []
# Actual Time:  38500
# Exit Time:  40500
# []
# Actual Time:  38600
# Exit Time:  40600
# []
# Actual Time:  38700
# Exit Time:  40700
# []
# Actual Time:  38800
# Exit Time:  40800
# []
# Actual Time:  38900
# Exit Time:  40900
# []
# Actual Time:  39000
# Exit Time:  41000
# []
# Actual Time:  39100
# Exit Time:  41100
# []
# Actual Time:  39200
# Exit Time:  41200
# []
# Actual Time:  39300
# Exit Time:  41300
# []
# Actual Time:  39400
# Exit Time:  41400
# []
# Actual Time:  39500
# Exit Time:  41500
# []
# Actual Time:  39600
# Exit Time:  41600
# []
# Actual Time:  39700
# Exit Time:  41700
# []
# Actual Time:  39800
# Exit Time:  41800
# []
# Actual Time:  39900
# Exit Time:  41900
# []
# Actual Time:  40000
# Exit Time:  42000
# []
# Actual Time:  40100
# Exit Time:  42100
# []
# Actual Time:  40200
# Exit Time:  42200
# []
# Actual Time:  40300
# Exit Time:  42300
# []
# Actual Time:  40400
# Exit Time:  42400
# []
# Actual Time:  40500
# Exit Time:  42500
# []
# Actual Time:  40600
# Exit Time:  42600
# []
# Actual Time:  40700
# Exit Time:  42700
# []
# Actual Time:  40800
# Exit Time:  42800
# []
# Actual Time:  40900
# Exit Time:  42900
# []
# Actual Time:  41000
# Exit Time:  43000
# []
# Actual Time:  41100
# Exit Time:  43100
# []
# Actual Time:  41200
# Exit Time:  43200
# []
# Actual Time:  41300
# Exit Time:  43300
# []
# Actual Time:  41400
# Exit Time:  43400
# []
# Actual Time:  41500
# Exit Time:  43500
# [(SQUID_INK, 1986, -1)]
# Actual Time:  41600
# Exit Time:  43600
# []
# Actual Time:  41700
# Exit Time:  43700
# []
# Actual Time:  41800
# Exit Time:  43800
# []
# Actual Time:  41900
# Exit Time:  43900
# []
# Actual Time:  42000
# Exit Time:  44000
# []
# Actual Time:  42100
# Exit Time:  44100
# []
# Actual Time:  42200
# Exit Time:  44200
# [(SQUID_INK, 1987, -1)]
# Actual Time:  42300
# Exit Time:  44300
# [(SQUID_INK, 1986, -1)]
# Actual Time:  42400
# Exit Time:  44400
# []
# Actual Time:  42500
# Exit Time:  44500
# []
# Actual Time:  42600
# Exit Time:  44600
# []
# Actual Time:  42700
# Exit Time:  44700
# []
# Actual Time:  42800
# Exit Time:  44800
# []
# Actual Time:  42900
# Exit Time:  44900
# []
# Actual Time:  43000
# Exit Time:  45000
# []
# Actual Time:  43100
# Exit Time:  45100
# []
# Actual Time:  43200
# Exit Time:  45200
# []
# Actual Time:  43300
# Exit Time:  45300
# []
# Actual Time:  43400
# Exit Time:  45400
# []
# Actual Time:  43500
# Exit Time:  45500
# [(SQUID_INK, 1985, 1)]
# Actual Time:  43600
# Exit Time:  45600
# []
# Actual Time:  43700
# Exit Time:  45700
# []
# Actual Time:  43800
# Exit Time:  45800
# []
# Actual Time:  43900
# Exit Time:  45900
# []
# Actual Time:  44000
# Exit Time:  46000
# []
# Actual Time:  44100
# Exit Time:  46100
# []
# Actual Time:  44200
# Exit Time:  46200
# [(SQUID_INK, 1991, 1)]
# Actual Time:  44300
# Exit Time:  46300
# [(SQUID_INK, 1990, 1)]
# Actual Time:  44400
# Exit Time:  46400
# []
# Actual Time:  44500
# Exit Time:  46500
# []
# Actual Time:  44600
# Exit Time:  46600
# []
# Actual Time:  44700
# Exit Time:  46700
# []
# Actual Time:  44800
# Exit Time:  46800
# []
# Actual Time:  44900
# Exit Time:  46900
# []
# Actual Time:  45000
# Exit Time:  47000
# []
# Actual Time:  45100
# Exit Time:  47100
# []
# Actual Time:  45200
# Exit Time:  47200
# []
# Actual Time:  45300
# Exit Time:  47300
# []
# Actual Time:  45400
# Exit Time:  47400
# []
# Actual Time:  45500
# Exit Time:  47500
# []
# Actual Time:  45600
# Exit Time:  47600
# []
# Actual Time:  45700
# Exit Time:  47700
# []
# Actual Time:  45800
# Exit Time:  47800
# []
# Actual Time:  45900
# Exit Time:  47900
# []
# Actual Time:  46000
# Exit Time:  48000
# []
# Actual Time:  46100
# Exit Time:  48100
# []
# Actual Time:  46200
# Exit Time:  48200
# []
# Actual Time:  46300
# Exit Time:  48300
# []
# Actual Time:  46400
# Exit Time:  48400
# []
# Actual Time:  46500
# Exit Time:  48500
# []
# Actual Time:  46600
# Exit Time:  48600
# []
# Actual Time:  46700
# Exit Time:  48700
# []
# Actual Time:  46800
# Exit Time:  48800
# []
# Actual Time:  46900
# Exit Time:  48900
# []
# Actual Time:  47000
# Exit Time:  49000
# []
# Actual Time:  47100
# Exit Time:  49100
# []
# Actual Time:  47200
# Exit Time:  49200
# []
# Actual Time:  47300
# Exit Time:  49300
# []
# Actual Time:  47400
# Exit Time:  49400
# []
# Actual Time:  47500
# Exit Time:  49500
# []
# Actual Time:  47600
# Exit Time:  49600
# []
# Actual Time:  47700
# Exit Time:  49700
# []
# Actual Time:  47800
# Exit Time:  49800
# []
# Actual Time:  47900
# Exit Time:  49900
# []
# Actual Time:  48000
# Exit Time:  50000
# []
# Actual Time:  48100
# Exit Time:  50100
# []
# Actual Time:  48200
# Exit Time:  50200
# []
# Actual Time:  48300
# Exit Time:  50300
# []
# Actual Time:  48400
# Exit Time:  50400
# []
# Actual Time:  48500
# Exit Time:  50500
# []
# Actual Time:  48600
# Exit Time:  50600
# []
# Actual Time:  48700
# Exit Time:  50700
# []
# Actual Time:  48800
# Exit Time:  50800
# []
# Actual Time:  48900
# Exit Time:  50900
# []
# Actual Time:  49000
# Exit Time:  51000
# []
# Actual Time:  49100
# Exit Time:  51100
# []
# Actual Time:  49200
# Exit Time:  51200
# []
# Actual Time:  49300
# Exit Time:  51300
# []
# Actual Time:  49400
# Exit Time:  51400
# []
# Actual Time:  49500
# Exit Time:  51500
# []
# Actual Time:  49600
# Exit Time:  51600
# []
# Actual Time:  49700
# Exit Time:  51700
# []
# Actual Time:  49800
# Exit Time:  51800
# []
# Actual Time:  49900
# Exit Time:  51900
# []
# Actual Time:  50000
# Exit Time:  52000
# []
# Actual Time:  50100
# Exit Time:  52100
# []
# Actual Time:  50200
# Exit Time:  52200
# []
# Actual Time:  50300
# Exit Time:  52300
# []
# Actual Time:  50400
# Exit Time:  52400
# []
# Actual Time:  50500
# Exit Time:  52500
# []
# Actual Time:  50600
# Exit Time:  52600
# []
# Actual Time:  50700
# Exit Time:  52700
# [(SQUID_INK, 1987, -1)]
# Actual Time:  50800
# Exit Time:  52800
# [(SQUID_INK, 1985, -1)]
# Actual Time:  50900
# Exit Time:  52900
# [(SQUID_INK, 1986, -1)]
# Actual Time:  51000
# Exit Time:  53000
# [(SQUID_INK, 1986, -1)]
# Actual Time:  51100
# Exit Time:  53100
# []
# Actual Time:  51200
# Exit Time:  53200
# [(SQUID_INK, 1986, -1)]
# Actual Time:  51300
# Exit Time:  53300
# []
# Actual Time:  51400
# Exit Time:  53400
# [(SQUID_INK, 1982, -1)]
# Actual Time:  51500
# Exit Time:  53500
# []
# Actual Time:  51600
# Exit Time:  53600
# [(SQUID_INK, 1985, -1)]
# Actual Time:  51700
# Exit Time:  53700
# []
# Actual Time:  51800
# Exit Time:  53800
# []
# Actual Time:  51900
# Exit Time:  53900
# []
# Actual Time:  52000
# Exit Time:  54000
# []
# Actual Time:  52100
# Exit Time:  54100
# []
# Actual Time:  52200
# Exit Time:  54200
# []
# Actual Time:  52300
# Exit Time:  54300
# []
# Actual Time:  52400
# Exit Time:  54400
# []
# Actual Time:  52500
# Exit Time:  54500
# []
# Actual Time:  52600
# Exit Time:  54600
# []
# Actual Time:  52700
# Exit Time:  54700
# [(SQUID_INK, 1988, 1)]
# Actual Time:  52800
# Exit Time:  54800
# [(SQUID_INK, 1987, 1)]
# Actual Time:  52900
# Exit Time:  54900
# [(SQUID_INK, 1986, 1)]
# Actual Time:  53000
# Exit Time:  55000
# [(SQUID_INK, 1987, 1)]
# Actual Time:  53100
# Exit Time:  55100
# []
# Actual Time:  53200
# Exit Time:  55200
# [(SQUID_INK, 1985, 1)]
# Actual Time:  53300
# Exit Time:  55300
# []
# Actual Time:  53400
# Exit Time:  55400
# [(SQUID_INK, 1985, 1)]
# Actual Time:  53500
# Exit Time:  55500
# []
# Actual Time:  53600
# Exit Time:  55600
# [(SQUID_INK, 1986, 1)]
# Actual Time:  53700
# Exit Time:  55700
# []
# Actual Time:  53800
# Exit Time:  55800
# []
# Actual Time:  53900
# Exit Time:  55900
# []
# Actual Time:  54000
# Exit Time:  56000
# []
# Actual Time:  54100
# Exit Time:  56100
# []
# Actual Time:  54200
# Exit Time:  56200
# []
# Actual Time:  54300
# Exit Time:  56300
# []
# Actual Time:  54400
# Exit Time:  56400
# []
# Actual Time:  54500
# Exit Time:  56500
# []
# Actual Time:  54600
# Exit Time:  56600
# []
# Actual Time:  54700
# Exit Time:  56700
# []
# Actual Time:  54800
# Exit Time:  56800
# []
# Actual Time:  54900
# Exit Time:  56900
# []
# Actual Time:  55000
# Exit Time:  57000
# []
# Actual Time:  55100
# Exit Time:  57100
# []
# Actual Time:  55200
# Exit Time:  57200
# []
# Actual Time:  55300
# Exit Time:  57300
# []
# Actual Time:  55400
# Exit Time:  57400
# []
# Actual Time:  55500
# Exit Time:  57500
# []
# Actual Time:  55600
# Exit Time:  57600
# []
# Actual Time:  55700
# Exit Time:  57700
# []
# Actual Time:  55800
# Exit Time:  57800
# []
# Actual Time:  55900
# Exit Time:  57900
# []
# Actual Time:  56000
# Exit Time:  58000
# []
# Actual Time:  56100
# Exit Time:  58100
# [(SQUID_INK, 1990, 1)]
# Actual Time:  56200
# Exit Time:  58200
# [(SQUID_INK, 1990, 1)]
# Actual Time:  56300
# Exit Time:  58300
# [(SQUID_INK, 1991, 1)]
# Actual Time:  56400
# Exit Time:  58400
# [(SQUID_INK, 1991, 1)]
# Actual Time:  56500
# Exit Time:  58500
# [(SQUID_INK, 1991, 1)]
# Actual Time:  56600
# Exit Time:  58600
# [(SQUID_INK, 1990, 1)]
# Actual Time:  56700
# Exit Time:  58700
# [(SQUID_INK, 1991, 1)]
# Actual Time:  56800
# Exit Time:  58800
# [(SQUID_INK, 1989, 1)]
# Actual Time:  56900
# Exit Time:  58900
# [(SQUID_INK, 1989, 1)]
# Actual Time:  57000
# Exit Time:  59000
# [(SQUID_INK, 1990, 1)]
# Actual Time:  57100
# Exit Time:  59100
# [(SQUID_INK, 1990, 1)]
# Actual Time:  57200
# Exit Time:  59200
# [(SQUID_INK, 1990, 1)]
# Actual Time:  57300
# Exit Time:  59300
# []
# Actual Time:  57400
# Exit Time:  59400
# []
# Actual Time:  57500
# Exit Time:  59500
# []
# Actual Time:  57600
# Exit Time:  59600
# [(SQUID_INK, 1992, 1)]
# Actual Time:  57700
# Exit Time:  59700
# [(SQUID_INK, 1992, 1)]
# Actual Time:  57800
# Exit Time:  59800
# [(SQUID_INK, 1991, 1)]
# Actual Time:  57900
# Exit Time:  59900
# [(SQUID_INK, 1992, 1)]
# Actual Time:  58000
# Exit Time:  60000
# [(SQUID_INK, 1994, 1)]
# Actual Time:  58100
# Exit Time:  60100
# [(SQUID_INK, 1991, 1)]
# Actual Time:  58200
# Exit Time:  60200
# [(SQUID_INK, 1991, 1)]
# Actual Time:  58300
# Exit Time:  60300
# [(SQUID_INK, 1991, 1)]
# Actual Time:  58400
# Exit Time:  60400
# [(SQUID_INK, 1991, 1)]
# Actual Time:  58500
# Exit Time:  60500
# [(SQUID_INK, 1993, 1)]
# Actual Time:  58600
# Exit Time:  60600
# [(SQUID_INK, 1992, 1)]
# Actual Time:  58700
# Exit Time:  60700
# [(SQUID_INK, 1993, 1)]
# Actual Time:  58800
# Exit Time:  60800
# [(SQUID_INK, 1993, 1)]
# Actual Time:  58900
# Exit Time:  60900
# [(SQUID_INK, 1993, 1)]
# Actual Time:  59000
# Exit Time:  61000
# [(SQUID_INK, 1993, 1)]
# Actual Time:  59100
# Exit Time:  61100
# [(SQUID_INK, 1993, 1)]
# Actual Time:  59200
# Exit Time:  61200
# [(SQUID_INK, 1992, 1)]
# Actual Time:  59300
# Exit Time:  61300
# [(SQUID_INK, 1992, 1)]
# Actual Time:  59400
# Exit Time:  61400
# [(SQUID_INK, 1991, 1)]
# Actual Time:  59500
# Exit Time:  61500
# [(SQUID_INK, 1991, 1)]
# Actual Time:  59600
# Exit Time:  61600
# [(SQUID_INK, 1991, 1)]
# Actual Time:  59700
# Exit Time:  61700
# [(SQUID_INK, 1990, 1)]
# Actual Time:  59800
# Exit Time:  61800
# [(SQUID_INK, 1991, 1)]
# Actual Time:  59900
# Exit Time:  61900
# [(SQUID_INK, 1990, 1)]
# Actual Time:  60000
# Exit Time:  62000
# [(SQUID_INK, 1992, 1)]
# Actual Time:  60100
# Exit Time:  62100
# [(SQUID_INK, 1990, 1)]
# Actual Time:  60200
# Exit Time:  62200
# [(SQUID_INK, 1986, 1)]
# Actual Time:  60300
# Exit Time:  62300
# [(SQUID_INK, 1988, 1)]
# Actual Time:  60400
# Exit Time:  62400
# [(SQUID_INK, 1989, 1)]
# Actual Time:  60500
# Exit Time:  62500
# [(SQUID_INK, 1987, 1)]
# Actual Time:  60600
# Exit Time:  62600
# [(SQUID_INK, 1987, 1)]
# Actual Time:  60700
# Exit Time:  62700
# []
# Actual Time:  60800
# Exit Time:  62800
# []
# Actual Time:  60900
# Exit Time:  62900
# []
# Actual Time:  61000
# Exit Time:  63000
# []
# Actual Time:  61100
# Exit Time:  63100
# []
# Actual Time:  61200
# Exit Time:  63200
# []
# Actual Time:  61300
# Exit Time:  63300
# []
# Actual Time:  61400
# Exit Time:  63400
# []
# Actual Time:  61500
# Exit Time:  63500
# []
# Actual Time:  61600
# Exit Time:  63600
# []
# Actual Time:  61700
# Exit Time:  63700
# []
# Actual Time:  61800
# Exit Time:  63800
# []
# Actual Time:  61900
# Exit Time:  63900
# []
# Actual Time:  62000
# Exit Time:  64000
# []
# Actual Time:  62100
# Exit Time:  64100
# []
# Actual Time:  62200
# Exit Time:  64200
# [(SQUID_INK, 1994, 1)]
# Actual Time:  62300
# Exit Time:  64300
# [(SQUID_INK, 1998, 1)]
# Actual Time:  62400
# Exit Time:  64400
# [(SQUID_INK, 1999, 1)]
# Actual Time:  62500
# Exit Time:  64500
# [(SQUID_INK, 2002, 1)]
# Actual Time:  62600
# Exit Time:  64600
# [(SQUID_INK, 2002, 1)]
# Actual Time:  62700
# Exit Time:  64700
# [(SQUID_INK, 2003, 1)]
# Actual Time:  62800
# Exit Time:  64800
# [(SQUID_INK, 2004, 1)]
# Actual Time:  62900
# Exit Time:  64900
# [(SQUID_INK, 2003, 1)]
# Actual Time:  63000
# Exit Time:  65000
# [(SQUID_INK, 2001, 1)]
# Actual Time:  63100
# Exit Time:  65100
# [(SQUID_INK, 2000, 1)]
# Actual Time:  63200
# Exit Time:  65200
# [(SQUID_INK, 2001, 1)]
# Actual Time:  63300
# Exit Time:  65300
# [(SQUID_INK, 2002, 1)]
# Actual Time:  63400
# Exit Time:  65400
# [(SQUID_INK, 2003, 1)]
# Actual Time:  63500
# Exit Time:  65500
# [(SQUID_INK, 2002, 1)]
# Actual Time:  63600
# Exit Time:  65600
# [(SQUID_INK, 2003, 1)]
# Actual Time:  63700
# Exit Time:  65700
# [(SQUID_INK, 2003, 1)]
# Actual Time:  63800
# Exit Time:  65800
# [(SQUID_INK, 2003, 1)]
# Actual Time:  63900
# Exit Time:  65900
# [(SQUID_INK, 2004, 1)]
# Actual Time:  64000
# Exit Time:  66000
# [(SQUID_INK, 2002, 1)]
# Actual Time:  64100
# Exit Time:  66100
# []
# Actual Time:  64200
# Exit Time:  66200
# [(SQUID_INK, 2003, -1)]
# Actual Time:  64300
# Exit Time:  66300
# [(SQUID_INK, 2003, -1)]
# Actual Time:  64400
# Exit Time:  66400
# [(SQUID_INK, 2003, -1)]
# Actual Time:  64500
# Exit Time:  66500
# [(SQUID_INK, 2004, -1)]
# Actual Time:  64600
# Exit Time:  66600
# [(SQUID_INK, 2005, -1)]
# Actual Time:  64700
# Exit Time:  66700
# []
# Actual Time:  64800
# Exit Time:  66800
# [(SQUID_INK, 2005, -1)]
# Actual Time:  64900
# Exit Time:  66900
# [(SQUID_INK, 2003, -1)]
# Actual Time:  65000
# Exit Time:  67000
# [(SQUID_INK, 2003, -1)]
# Actual Time:  65100
# Exit Time:  67100
# [(SQUID_INK, 2004, -1)]
# Actual Time:  65200
# Exit Time:  67200
# [(SQUID_INK, 2004, -1)]
# Actual Time:  65300
# Exit Time:  67300
# [(SQUID_INK, 2004, -1)]
# Actual Time:  65400
# Exit Time:  67400
# [(SQUID_INK, 2004, -1)]
# Actual Time:  65500
# Exit Time:  67500
# [(SQUID_INK, 2005, -1)]
# Actual Time:  65600
# Exit Time:  67600
# [(SQUID_INK, 2006, -1)]
# Actual Time:  65700
# Exit Time:  67700
# [(SQUID_INK, 2005, -1)]
# Actual Time:  65800
# Exit Time:  67800
# [(SQUID_INK, 2006, -1)]
# Actual Time:  65900
# Exit Time:  67900
# [(SQUID_INK, 2005, -1)]
# Actual Time:  66000
# Exit Time:  68000
# [(SQUID_INK, 2005, -1)]
# Actual Time:  66100
# Exit Time:  68100
# []
# Actual Time:  66200
# Exit Time:  68200
# []
# Actual Time:  66300
# Exit Time:  68300
# []
# Actual Time:  66400
# Exit Time:  68400
# []
# Actual Time:  66500
# Exit Time:  68500
# []
# Actual Time:  66600
# Exit Time:  68600
# []
# Actual Time:  66700
# Exit Time:  68700
# [(SQUID_INK, 2006, -1)]
# Actual Time:  66800
# Exit Time:  68800
# []
# Actual Time:  66900
# Exit Time:  68900
# []
# Actual Time:  67000
# Exit Time:  69000
# []
# Actual Time:  67100
# Exit Time:  69100
# []
# Actual Time:  67200
# Exit Time:  69200
# []
# Actual Time:  67300
# Exit Time:  69300
# []
# Actual Time:  67400
# Exit Time:  69400
# []
# Actual Time:  67500
# Exit Time:  69500
# []
# Actual Time:  67600
# Exit Time:  69600
# []
# Actual Time:  67700
# Exit Time:  69700
# []
# Actual Time:  67800
# Exit Time:  69800
# []
# Actual Time:  67900
# Exit Time:  69900
# []
# Actual Time:  68000
# Exit Time:  70000
# []
# Actual Time:  68100
# Exit Time:  70100
# []
# Actual Time:  68200
# Exit Time:  70200
# []
# Actual Time:  68300
# Exit Time:  70300
# []
# Actual Time:  68400
# Exit Time:  70400
# []
# Actual Time:  68500
# Exit Time:  70500
# []
# Actual Time:  68600
# Exit Time:  70600
# []
# Actual Time:  68700
# Exit Time:  70700
# []
# Actual Time:  68800
# Exit Time:  70800
# []
# Actual Time:  68900
# Exit Time:  70900
# []
# Actual Time:  69000
# Exit Time:  71000
# []
# Actual Time:  69100
# Exit Time:  71100
# []
# Actual Time:  69200
# Exit Time:  71200
# []
# Actual Time:  69300
# Exit Time:  71300
# []
# Actual Time:  69400
# Exit Time:  71400
# []
# Actual Time:  69500
# Exit Time:  71500
# []
# Actual Time:  69600
# Exit Time:  71600
# []
# Actual Time:  69700
# Exit Time:  71700
# []
# Actual Time:  69800
# Exit Time:  71800
# []
# Actual Time:  69900
# Exit Time:  71900
# []
# Actual Time:  70000
# Exit Time:  72000
# []
# Actual Time:  70100
# Exit Time:  72100
# []
# Actual Time:  70200
# Exit Time:  72200
# []
# Actual Time:  70300
# Exit Time:  72300
# []
# Actual Time:  70400
# Exit Time:  72400
# []
# Actual Time:  70500
# Exit Time:  72500
# []
# Actual Time:  70600
# Exit Time:  72600
# []
# Actual Time:  70700
# Exit Time:  72700
# []
# Actual Time:  70800
# Exit Time:  72800
# []
# Actual Time:  70900
# Exit Time:  72900
# []
# Actual Time:  71000
# Exit Time:  73000
# []
# Actual Time:  71100
# Exit Time:  73100
# []
# Actual Time:  71200
# Exit Time:  73200
# []
# Actual Time:  71300
# Exit Time:  73300
# []
# Actual Time:  71400
# Exit Time:  73400
# []
# Actual Time:  71500
# Exit Time:  73500
# []
# Actual Time:  71600
# Exit Time:  73600
# []
# Actual Time:  71700
# Exit Time:  73700
# []
# Actual Time:  71800
# Exit Time:  73800
# []
# Actual Time:  71900
# Exit Time:  73900
# []
# Actual Time:  72000
# Exit Time:  74000
# []
# Actual Time:  72100
# Exit Time:  74100
# []
# Actual Time:  72200
# Exit Time:  74200
# []
# Actual Time:  72300
# Exit Time:  74300
# []
# Actual Time:  72400
# Exit Time:  74400
# []
# Actual Time:  72500
# Exit Time:  74500
# []
# Actual Time:  72600
# Exit Time:  74600
# []
# Actual Time:  72700
# Exit Time:  74700
# []
# Actual Time:  72800
# Exit Time:  74800
# []
# Actual Time:  72900
# Exit Time:  74900
# []
# Actual Time:  73000
# Exit Time:  75000
# []
# Actual Time:  73100
# Exit Time:  75100
# []
# Actual Time:  73200
# Exit Time:  75200
# []
# Actual Time:  73300
# Exit Time:  75300
# []
# Actual Time:  73400
# Exit Time:  75400
# []
# Actual Time:  73500
# Exit Time:  75500
# []
# Actual Time:  73600
# Exit Time:  75600
# []
# Actual Time:  73700
# Exit Time:  75700
# []
# Actual Time:  73800
# Exit Time:  75800
# []
# Actual Time:  73900
# Exit Time:  75900
# []
# Actual Time:  74000
# Exit Time:  76000
# []
# Actual Time:  74100
# Exit Time:  76100
# []
# Actual Time:  74200
# Exit Time:  76200
# []
# Actual Time:  74300
# Exit Time:  76300
# []
# Actual Time:  74400
# Exit Time:  76400
# []
# Actual Time:  74500
# Exit Time:  76500
# []
# Actual Time:  74600
# Exit Time:  76600
# []
# Actual Time:  74700
# Exit Time:  76700
# []
# Actual Time:  74800
# Exit Time:  76800
# []
# Actual Time:  74900
# Exit Time:  76900
# []
# Actual Time:  75000
# Exit Time:  77000
# []
# Actual Time:  75100
# Exit Time:  77100
# []
# Actual Time:  75200
# Exit Time:  77200
# []
# Actual Time:  75300
# Exit Time:  77300
# []
# Actual Time:  75400
# Exit Time:  77400
# []
# Actual Time:  75500
# Exit Time:  77500
# []
# Actual Time:  75600
# Exit Time:  77600
# []
# Actual Time:  75700
# Exit Time:  77700
# []
# Actual Time:  75800
# Exit Time:  77800
# []
# Actual Time:  75900
# Exit Time:  77900
# []
# Actual Time:  76000
# Exit Time:  78000
# []
# Actual Time:  76100
# Exit Time:  78100
# []
# Actual Time:  76200
# Exit Time:  78200
# []
# Actual Time:  76300
# Exit Time:  78300
# []
# Actual Time:  76400
# Exit Time:  78400
# []
# Actual Time:  76500
# Exit Time:  78500
# []
# Actual Time:  76600
# Exit Time:  78600
# []
# Actual Time:  76700
# Exit Time:  78700
# []
# Actual Time:  76800
# Exit Time:  78800
# []
# Actual Time:  76900
# Exit Time:  78900
# []
# Actual Time:  77000
# Exit Time:  79000
# []
# Actual Time:  77100
# Exit Time:  79100
# []
# Actual Time:  77200
# Exit Time:  79200
# [(SQUID_INK, 2000, -1)]
# Actual Time:  77300
# Exit Time:  79300
# [(SQUID_INK, 2000, -1)]
# Actual Time:  77400
# Exit Time:  79400
# [(SQUID_INK, 2000, -1)]
# Actual Time:  77500
# Exit Time:  79500
# []
# Actual Time:  77600
# Exit Time:  79600
# []
# Actual Time:  77700
# Exit Time:  79700
# []
# Actual Time:  77800
# Exit Time:  79800
# []
# Actual Time:  77900
# Exit Time:  79900
# []
# Actual Time:  78000
# Exit Time:  80000
# []
# Actual Time:  78100
# Exit Time:  80100
# []
# Actual Time:  78200
# Exit Time:  80200
# [(SQUID_INK, 2000, -1)]
# Actual Time:  78300
# Exit Time:  80300
# [(SQUID_INK, 2000, -1)]
# Actual Time:  78400
# Exit Time:  80400
# [(SQUID_INK, 2000, -1)]
# Actual Time:  78500
# Exit Time:  80500
# []
# Actual Time:  78600
# Exit Time:  80600
# []
# Actual Time:  78700
# Exit Time:  80700
# []
# Actual Time:  78800
# Exit Time:  80800
# []
# Actual Time:  78900
# Exit Time:  80900
# []
# Actual Time:  79000
# Exit Time:  81000
# []
# Actual Time:  79100
# Exit Time:  81100
# []
# Actual Time:  79200
# Exit Time:  81200
# [(SQUID_INK, 2000, 1)]
# Actual Time:  79300
# Exit Time:  81300
# [(SQUID_INK, 2000, 1)]
# Actual Time:  79400
# Exit Time:  81400
# [(SQUID_INK, 2000, 1)]
# Actual Time:  79500
# Exit Time:  81500
# [(SQUID_INK, 2004, -1)]
# Actual Time:  79600
# Exit Time:  81600
# [(SQUID_INK, 2004, -1)]
# Actual Time:  79700
# Exit Time:  81700
# [(SQUID_INK, 2004, -1)]
# Actual Time:  79800
# Exit Time:  81800
# [(SQUID_INK, 2001, -1)]
# Actual Time:  79900
# Exit Time:  81900
# [(SQUID_INK, 2001, -1)]
# Actual Time:  80000
# Exit Time:  82000
# [(SQUID_INK, 1997, -1), (SQUID_INK, 1997, -1)]
# Actual Time:  80100
# Exit Time:  82100
# [(SQUID_INK, 1996, -1), (SQUID_INK, 1996, -1)]
# Actual Time:  80200
# Exit Time:  82200
# []
# Actual Time:  80300
# Exit Time:  82300
# []
# Actual Time:  80400
# Exit Time:  82400
# []
# Actual Time:  80500
# Exit Time:  82500
# [(SQUID_INK, 1995, -1), (SQUID_INK, 1995, -1)]
# Actual Time:  80600
# Exit Time:  82600
# [(SQUID_INK, 1997, -1), (SQUID_INK, 1997, -1)]
# Actual Time:  80700
# Exit Time:  82700
# [(SQUID_INK, 1998, -1), (SQUID_INK, 1998, -1)]
# Actual Time:  80800
# Exit Time:  82800
# [(SQUID_INK, 1998, -1), (SQUID_INK, 1998, -1)]
# Actual Time:  80900
# Exit Time:  82900
# [(SQUID_INK, 1996, -1), (SQUID_INK, 1996, -1)]
# Actual Time:  81000
# Exit Time:  83000
# [(SQUID_INK, 1997, -1)]
# Actual Time:  81100
# Exit Time:  83100
# [(SQUID_INK, 1997, -1)]
# Actual Time:  81200
# Exit Time:  83200
# []
# Actual Time:  81300
# Exit Time:  83300
# []
# Actual Time:  81400
# Exit Time:  83400
# [(SQUID_INK, 1997, -1)]
# Actual Time:  81500
# Exit Time:  83500
# [(SQUID_INK, 1997, -1)]
# Actual Time:  81600
# Exit Time:  83600
# [(SQUID_INK, 1996, -1)]
# Actual Time:  81700
# Exit Time:  83700
# []
# Actual Time:  81800
# Exit Time:  83800
# [(SQUID_INK, 1995, -1)]
# Actual Time:  81900
# Exit Time:  83900
# [(SQUID_INK, 1995, -1)]
# Actual Time:  82000
# Exit Time:  84000
# [(SQUID_INK, 1995, 1)]
# Actual Time:  82100
# Exit Time:  84100
# []
# Actual Time:  82200
# Exit Time:  84200
# []
# Actual Time:  82300
# Exit Time:  84300
# [(SQUID_INK, 1993, 1)]
# Actual Time:  82400
# Exit Time:  84400
# []
# Actual Time:  82500
# Exit Time:  84500
# [(SQUID_INK, 1992, 1)]
# Actual Time:  82600
# Exit Time:  84600
# [(SQUID_INK, 1993, 1)]
# Actual Time:  82700
# Exit Time:  84700
# [(SQUID_INK, 1993, 1)]
# Actual Time:  82800
# Exit Time:  84800
# []
# Actual Time:  82900
# Exit Time:  84900
# []
# Actual Time:  83000
# Exit Time:  85000
# []
# Actual Time:  83100
# Exit Time:  85100
# [(SQUID_INK, 1992, 1)]
# Actual Time:  83200
# Exit Time:  85200
# []
# Actual Time:  83300
# Exit Time:  85300
# []
# Actual Time:  83400
# Exit Time:  85400
# [(SQUID_INK, 1994, 1)]
# Actual Time:  83500
# Exit Time:  85500
# [(SQUID_INK, 1992, 1)]
# Actual Time:  83600
# Exit Time:  85600
# [(SQUID_INK, 1993, 1)]
# Actual Time:  83700
# Exit Time:  85700
# []
# Actual Time:  83800
# Exit Time:  85800
# [(SQUID_INK, 1995, 1)]
# Actual Time:  83900
# Exit Time:  85900
# [(SQUID_INK, 1997, 1)]
# Actual Time:  84000
# Exit Time:  86000
# []
# Actual Time:  84100
# Exit Time:  86100
# [(SQUID_INK, 1997, 1)]
# Actual Time:  84200
# Exit Time:  86200
# [(SQUID_INK, 1999, 1)]
# Actual Time:  84300
# Exit Time:  86300
# []
# Actual Time:  84400
# Exit Time:  86400
# [(SQUID_INK, 1997, 1)]
# Actual Time:  84500
# Exit Time:  86500
# []
# Actual Time:  84600
# Exit Time:  86600
# []
# Actual Time:  84700
# Exit Time:  86700
# []
# Actual Time:  84800
# Exit Time:  86800
# [(SQUID_INK, 1997, 1)]
# Actual Time:  84900
# Exit Time:  86900
# [(SQUID_INK, 1997, 1)]
# Actual Time:  85000
# Exit Time:  87000
# [(SQUID_INK, 1996, 1)]
# Actual Time:  85100
# Exit Time:  87100
# []
# Actual Time:  85200
# Exit Time:  87200
# [(SQUID_INK, 1996, 1)]
# Actual Time:  85300
# Exit Time:  87300
# [(SQUID_INK, 1997, 1)]
# Actual Time:  85400
# Exit Time:  87400
# []
# Actual Time:  85500
# Exit Time:  87500
# []
# Actual Time:  85600
# Exit Time:  87600
# []
# Actual Time:  85700
# Exit Time:  87700
# [(SQUID_INK, 1996, 1)]
# Actual Time:  85800
# Exit Time:  87800
# [(SQUID_INK, 1997, 1)]
# Actual Time:  85900
# Exit Time:  87900
# [(SQUID_INK, 1997, 1)]
# Actual Time:  86000
# Exit Time:  88000
# [(SQUID_INK, 1998, 1)]
# Actual Time:  86100
# Exit Time:  88100
# [(SQUID_INK, 1998, 1)]
# Actual Time:  86200
# Exit Time:  88200
# [(SQUID_INK, 1998, 1)]
# Actual Time:  86300
# Exit Time:  88300
# [(SQUID_INK, 1998, 1)]
# Actual Time:  86400
# Exit Time:  88400
# [(SQUID_INK, 1999, 1)]
# Actual Time:  86500
# Exit Time:  88500
# [(SQUID_INK, 1999, 1)]
# Actual Time:  86600
# Exit Time:  88600
# [(SQUID_INK, 2000, 1)]
# Actual Time:  86700
# Exit Time:  88700
# [(SQUID_INK, 2000, 1)]
# Actual Time:  86800
# Exit Time:  88800
# [(SQUID_INK, 2000, 1)]
# Actual Time:  86900
# Exit Time:  88900
# [(SQUID_INK, 1999, 1)]
# Actual Time:  87000
# Exit Time:  89000
# [(SQUID_INK, 2000, 1)]
# Actual Time:  87100
# Exit Time:  89100
# [(SQUID_INK, 2001, 1)]
# Actual Time:  87200
# Exit Time:  89200
# [(SQUID_INK, 1999, 1)]
# Actual Time:  87300
# Exit Time:  89300
# [(SQUID_INK, 1998, 1)]
# Actual Time:  87400
# Exit Time:  89400
# [(SQUID_INK, 1998, 1)]
# Actual Time:  87500
# Exit Time:  89500
# [(SQUID_INK, 1998, 1)]
# Actual Time:  87600
# Exit Time:  89600
# [(SQUID_INK, 1998, 1)]
# Actual Time:  87700
# Exit Time:  89700
# [(SQUID_INK, 1998, 1)]
# Actual Time:  87800
# Exit Time:  89800
# [(SQUID_INK, 1997, 1)]
# Actual Time:  87900
# Exit Time:  89900
# [(SQUID_INK, 1999, 1)]
# Actual Time:  88000
# Exit Time:  90000
# [(SQUID_INK, 1997, 1)]
# Actual Time:  88100
# Exit Time:  90100
# [(SQUID_INK, 1996, 1)]
# Actual Time:  88200
# Exit Time:  90200
# [(SQUID_INK, 1997, 1)]
# Actual Time:  88300
# Exit Time:  90300
# [(SQUID_INK, 1998, 1)]
# Actual Time:  88400
# Exit Time:  90400
# [(SQUID_INK, 1998, 1)]
# Actual Time:  88500
# Exit Time:  90500
# [(SQUID_INK, 1996, 1)]
# Actual Time:  88600
# Exit Time:  90600
# [(SQUID_INK, 1996, 1)]
# Actual Time:  88700
# Exit Time:  90700
# [(SQUID_INK, 1995, 1)]
# Actual Time:  88800
# Exit Time:  90800
# [(SQUID_INK, 1994, 1)]
# Actual Time:  88900
# Exit Time:  90900
# [(SQUID_INK, 1994, 1)]
# Actual Time:  89000
# Exit Time:  91000
# [(SQUID_INK, 1992, 1)]
# Actual Time:  89100
# Exit Time:  91100
# [(SQUID_INK, 1993, 1)]
# Actual Time:  89200
# Exit Time:  91200
# [(SQUID_INK, 1993, 1)]
# Actual Time:  89300
# Exit Time:  91300
# []
# Actual Time:  89400
# Exit Time:  91400
# [(SQUID_INK, 1994, 1)]
# Actual Time:  89500
# Exit Time:  91500
# [(SQUID_INK, 1993, 1)]
# Actual Time:  89600
# Exit Time:  91600
# []
# Actual Time:  89700
# Exit Time:  91700
# []
# Actual Time:  89800
# Exit Time:  91800
# []
# Actual Time:  89900
# Exit Time:  91900
# []
# Actual Time:  90000
# Exit Time:  92000
# []
# Actual Time:  90100
# Exit Time:  92100
# []
# Actual Time:  90200
# Exit Time:  92200
# []
# Actual Time:  90300
# Exit Time:  92300
# []
# Actual Time:  90400
# Exit Time:  92400
# []
# Actual Time:  90500
# Exit Time:  92500
# []
# Actual Time:  90600
# Exit Time:  92600
# []
# Actual Time:  90700
# Exit Time:  92700
# []
# Actual Time:  90800
# Exit Time:  92800
# []
# Actual Time:  90900
# Exit Time:  92900
# []
# Actual Time:  91000
# Exit Time:  93000
# []
# Actual Time:  91100
# Exit Time:  93100
# []
# Actual Time:  91200
# Exit Time:  93200
# []
# Actual Time:  91300
# Exit Time:  93300
# []
# Actual Time:  91400
# Exit Time:  93400
# []
# Actual Time:  91500
# Exit Time:  93500
# [(SQUID_INK, 1991, -1)]
# Actual Time:  91600
# Exit Time:  93600
# [(SQUID_INK, 1992, -1)]
# Actual Time:  91700
# Exit Time:  93700
# [(SQUID_INK, 1992, -1)]
# Actual Time:  91800
# Exit Time:  93800
# []
# Actual Time:  91900
# Exit Time:  93900
# []
# Actual Time:  92000
# Exit Time:  94000
# []
# Actual Time:  92100
# Exit Time:  94100
# []
# Actual Time:  92200
# Exit Time:  94200
# []
# Actual Time:  92300
# Exit Time:  94300
# []
# Actual Time:  92400
# Exit Time:  94400
# []
# Actual Time:  92500
# Exit Time:  94500
# []
# Actual Time:  92600
# Exit Time:  94600
# [(SQUID_INK, 1990, -1)]
# Actual Time:  92700
# Exit Time:  94700
# []
# Actual Time:  92800
# Exit Time:  94800
# []
# Actual Time:  92900
# Exit Time:  94900
# []
# Actual Time:  93000
# Exit Time:  95000
# []
# Actual Time:  93100
# Exit Time:  95100
# []
# Actual Time:  93200
# Exit Time:  95200
# []
# Actual Time:  93300
# Exit Time:  95300
# []
# Actual Time:  93400
# Exit Time:  95400
# []
# Actual Time:  93500
# Exit Time:  95500
# [(SQUID_INK, 1993, 1)]
# Actual Time:  93600
# Exit Time:  95600
# [(SQUID_INK, 1993, 1)]
# Actual Time:  93700
# Exit Time:  95700
# [(SQUID_INK, 1995, 1)]
# Actual Time:  93800
# Exit Time:  95800
# []
# Actual Time:  93900
# Exit Time:  95900
# []
# Actual Time:  94000
# Exit Time:  96000
# []
# Actual Time:  94100
# Exit Time:  96100
# []
# Actual Time:  94200
# Exit Time:  96200
# []
# Actual Time:  94300
# Exit Time:  96300
# []
# Actual Time:  94400
# Exit Time:  96400
# []
# Actual Time:  94500
# Exit Time:  96500
# []
# Actual Time:  94600
# Exit Time:  96600
# [(SQUID_INK, 1999, 1)]
# Actual Time:  94700
# Exit Time:  96700
# []
# Actual Time:  94800
# Exit Time:  96800
# []
# Actual Time:  94900
# Exit Time:  96900
# []
# Actual Time:  95000
# Exit Time:  97000
# []
# Actual Time:  95100
# Exit Time:  97100
# []
# Actual Time:  95200
# Exit Time:  97200
# []
# Actual Time:  95300
# Exit Time:  97300
# []
# Actual Time:  95400
# Exit Time:  97400
# []
# Actual Time:  95500
# Exit Time:  97500
# []
# Actual Time:  95600
# Exit Time:  97600
# []
# Actual Time:  95700
# Exit Time:  97700
# []
# Actual Time:  95800
# Exit Time:  97800
# []
# Actual Time:  95900
# Exit Time:  97900
# []
# Actual Time:  96000
# Exit Time:  98000
# []
# Actual Time:  96100
# Exit Time:  98100
# []
# Actual Time:  96200
# Exit Time:  98200
# []
# Actual Time:  96300
# Exit Time:  98300
# []
# Actual Time:  96400
# Exit Time:  98400
# []
# Actual Time:  96500
# Exit Time:  98500
# []
# Actual Time:  96600
# Exit Time:  98600
# []
# Actual Time:  96700
# Exit Time:  98700
# []
# Actual Time:  96800
# Exit Time:  98800
# []
# Actual Time:  96900
# Exit Time:  98900
# []
# Actual Time:  97000
# Exit Time:  99000
# []
# Actual Time:  97100
# Exit Time:  99100
# []
# Actual Time:  97200
# Exit Time:  99200
# []
# Actual Time:  97300
# Exit Time:  99300
# []
# Actual Time:  97400
# Exit Time:  99400
# []
# Actual Time:  97500
# Exit Time:  99500
# []
# Actual Time:  97600
# Exit Time:  99600
# []
# Actual Time:  97700
# Exit Time:  99700
# []
# Actual Time:  97800
# Exit Time:  99800
# []
# Actual Time:  97900
# Exit Time:  99900
# []
# Actual Time:  98000
# Exit Time:  100000
# []
# Actual Time:  98100
# Exit Time:  100100
# []
# Actual Time:  98200
# Exit Time:  100200
# []
# Actual Time:  98300
# Exit Time:  100300
# []
# Actual Time:  98400
# Exit Time:  100400
# []
# Actual Time:  98500
# Exit Time:  100500
# []
# Actual Time:  98600
# Exit Time:  100600
# []
# Actual Time:  98700
# Exit Time:  100700
# []
# Actual Time:  98800
# Exit Time:  100800
# []
# Actual Time:  98900
# Exit Time:  100900
# []
# Actual Time:  99000
# Exit Time:  101000
# []
# Actual Time:  99100
# Exit Time:  101100
# []
# Actual Time:  99200
# Exit Time:  101200
# []
# Actual Time:  99300
# Exit Time:  101300
# []
# Actual Time:  99400
# Exit Time:  101400
# []
# Actual Time:  99500
# Exit Time:  101500
# []
# Actual Time:  99600
# Exit Time:  101600
# []
# Actual Time:  99700
# Exit Time:  101700
# []
# Actual Time:  99800
# Exit Time:  101800
# []
# Actual Time:  99900
# Exit Time:  101900
# []
# Actual Time:  100000
# Exit Time:  102000
# []
# Actual Time:  100100
# Exit Time:  102100
# []
# Actual Time:  100200
# Exit Time:  102200
# []
# Actual Time:  100300
# Exit Time:  102300
# []
# Actual Time:  100400
# Exit Time:  102400
# []
# Actual Time:  100500
# ...
# []
# Actual Time:  967400
# Exit Time:  969400
# []
# Actual Time:  967500
# Exit Time:  969500
# []
# Actual Time:  967600
# Exit Time:  969600
# []
# Actual Time:  967700
# Exit Time:  969700
# []
# Actual Time:  967800
# Exit Time:  969800
# []
# Actual Time:  967900
# Exit Time:  969900
# []
# Actual Time:  968000
# Exit Time:  970000
# [(SQUID_INK, 2025, 1)]
# Actual Time:  968100
# Exit Time:  970100
# [(SQUID_INK, 2022, 1)]
# Actual Time:  968200
# Exit Time:  970200
# [(SQUID_INK, 2019, 1)]
# Actual Time:  968300
# Exit Time:  970300
# [(SQUID_INK, 2021, 1)]
# Actual Time:  968400
# Exit Time:  970400
# [(SQUID_INK, 2021, 1)]
# Actual Time:  968500
# Exit Time:  970500
# [(SQUID_INK, 2026, 1)]
# Actual Time:  968600
# Exit Time:  970600
# [(SQUID_INK, 2023, 1)]
# Actual Time:  968700
# Exit Time:  970700
# [(SQUID_INK, 2022, 1)]
# Actual Time:  968800
# Exit Time:  970800
# [(SQUID_INK, 2019, 1)]
# Actual Time:  968900
# Exit Time:  970900
# []
# Actual Time:  969000
# Exit Time:  971000
# []
# Actual Time:  969100
# Exit Time:  971100
# []
# Actual Time:  969200
# Exit Time:  971200
# []
# Actual Time:  969300
# Exit Time:  971300
# []
# Actual Time:  969400
# Exit Time:  971400
# []
# Actual Time:  969500
# Exit Time:  971500
# []
# Actual Time:  969600
# Exit Time:  971600
# []
# Actual Time:  969700
# Exit Time:  971700
# []
# Actual Time:  969800
# Exit Time:  971800
# []
# Actual Time:  969900
# Exit Time:  971900
# []
# Actual Time:  970000
# Exit Time:  972000
# []
# Actual Time:  970100
# Exit Time:  972100
# []
# Actual Time:  970200
# Exit Time:  972200
# []
# Actual Time:  970300
# Exit Time:  972300
# []
# Actual Time:  970400
# Exit Time:  972400
# []
# Actual Time:  970500
# Exit Time:  972500
# []
# Actual Time:  970600
# Exit Time:  972600
# [(SQUID_INK, 2012, -1)]
# Actual Time:  970700
# Exit Time:  972700
# [(SQUID_INK, 2009, -1)]
# Actual Time:  970800
# Exit Time:  972800
# [(SQUID_INK, 2010, -1)]
# Actual Time:  970900
# Exit Time:  972900
# [(SQUID_INK, 2009, -1)]
# Actual Time:  971000
# Exit Time:  973000
# [(SQUID_INK, 2007, -1)]
# Actual Time:  971100
# Exit Time:  973100
# [(SQUID_INK, 2008, -1)]
# Actual Time:  971200
# Exit Time:  973200
# [(SQUID_INK, 2009, -1)]
# Actual Time:  971300
# Exit Time:  973300
# [(SQUID_INK, 2009, -1)]
# Actual Time:  971400
# Exit Time:  973400
# [(SQUID_INK, 2010, -1)]
# Actual Time:  971500
# Exit Time:  973500
# []
# Actual Time:  971600
# Exit Time:  973600
# []
# Actual Time:  971700
# Exit Time:  973700
# []
# Actual Time:  971800
# Exit Time:  973800
# []
# Actual Time:  971900
# Exit Time:  973900
# []
# Actual Time:  972000
# Exit Time:  974000
# []
# Actual Time:  972100
# Exit Time:  974100
# []
# Actual Time:  972200
# Exit Time:  974200
# []
# Actual Time:  972300
# Exit Time:  974300
# []
# Actual Time:  972400
# Exit Time:  974400
# []
# Actual Time:  972500
# Exit Time:  974500
# []
# Actual Time:  972600
# Exit Time:  974600
# [(SQUID_INK, 2012, 1)]
# Actual Time:  972700
# Exit Time:  974700
# [(SQUID_INK, 2013, 1)]
# Actual Time:  972800
# Exit Time:  974800
# [(SQUID_INK, 2013, 1)]
# Actual Time:  972900
# Exit Time:  974900
# [(SQUID_INK, 2013, 1)]
# Actual Time:  973000
# Exit Time:  975000
# [(SQUID_INK, 2013, 1)]
# Actual Time:  973100
# Exit Time:  975100
# [(SQUID_INK, 2013, 1)]
# Actual Time:  973200
# Exit Time:  975200
# [(SQUID_INK, 2014, 1)]
# Actual Time:  973300
# Exit Time:  975300
# [(SQUID_INK, 2013, 1)]
# Actual Time:  973400
# Exit Time:  975400
# [(SQUID_INK, 2014, 1)]
# Actual Time:  973500
# Exit Time:  975500
# []
# Actual Time:  973600
# Exit Time:  975600
# []
# Actual Time:  973700
# Exit Time:  975700
# []
# Actual Time:  973800
# Exit Time:  975800
# []
# Actual Time:  973900
# Exit Time:  975900
# []
# Actual Time:  974000
# Exit Time:  976000
# []
# Actual Time:  974100
# Exit Time:  976100
# []
# Actual Time:  974200
# Exit Time:  976200
# []
# Actual Time:  974300
# Exit Time:  976300
# []
# Actual Time:  974400
# Exit Time:  976400
# []
# Actual Time:  974500
# Exit Time:  976500
# []
# Actual Time:  974600
# Exit Time:  976600
# []
# Actual Time:  974700
# Exit Time:  976700
# []
# Actual Time:  974800
# Exit Time:  976800
# []
# Actual Time:  974900
# Exit Time:  976900
# []
# Actual Time:  975000
# Exit Time:  977000
# []
# Actual Time:  975100
# Exit Time:  977100
# []
# Actual Time:  975200
# Exit Time:  977200
# []
# Actual Time:  975300
# Exit Time:  977300
# []
# Actual Time:  975400
# Exit Time:  977400
# []
# Actual Time:  975500
# Exit Time:  977500
# []
# Actual Time:  975600
# Exit Time:  977600
# []
# Actual Time:  975700
# Exit Time:  977700
# []
# Actual Time:  975800
# Exit Time:  977800
# []
# Actual Time:  975900
# Exit Time:  977900
# []
# Actual Time:  976000
# Exit Time:  978000
# []
# Actual Time:  976100
# Exit Time:  978100
# [(SQUID_INK, 2006, -1)]
# Actual Time:  976200
# Exit Time:  978200
# []
# Actual Time:  976300
# Exit Time:  978300
# []
# Actual Time:  976400
# Exit Time:  978400
# []
# Actual Time:  976500
# Exit Time:  978500
# []
# Actual Time:  976600
# Exit Time:  978600
# []
# Actual Time:  976700
# Exit Time:  978700
# []
# Actual Time:  976800
# Exit Time:  978800
# []
# Actual Time:  976900
# Exit Time:  978900
# []
# Actual Time:  977000
# Exit Time:  979000
# []
# Actual Time:  977100
# Exit Time:  979100
# []
# Actual Time:  977200
# Exit Time:  979200
# []
# Actual Time:  977300
# Exit Time:  979300
# []
# Actual Time:  977400
# Exit Time:  979400
# []
# Actual Time:  977500
# Exit Time:  979500
# [(SQUID_INK, 2006, 1)]
# Actual Time:  977600
# Exit Time:  979600
# [(SQUID_INK, 2008, 1)]
# Actual Time:  977700
# Exit Time:  979700
# []
# Actual Time:  977800
# Exit Time:  979800
# [(SQUID_INK, 2007, 1)]
# Actual Time:  977900
# Exit Time:  979900
# [(SQUID_INK, 2006, 1)]
# Actual Time:  978000
# Exit Time:  980000
# [(SQUID_INK, 2006, 1)]
# Actual Time:  978100
# Exit Time:  980100
# [(SQUID_INK, 2006, 1)]
# Actual Time:  978200
# Exit Time:  980200
# [(SQUID_INK, 2008, 1)]
# Actual Time:  978300
# Exit Time:  980300
# [(SQUID_INK, 2004, 1)]
# Actual Time:  978400
# Exit Time:  980400
# [(SQUID_INK, 2005, 1)]
# Actual Time:  978500
# Exit Time:  980500
# [(SQUID_INK, 2004, 1)]
# Actual Time:  978600
# Exit Time:  980600
# [(SQUID_INK, 2005, 1)]
# Actual Time:  978700
# Exit Time:  980700
# [(SQUID_INK, 2005, 1)]
# Actual Time:  978800
# Exit Time:  980800
# [(SQUID_INK, 2005, 1)]
# Actual Time:  978900
# Exit Time:  980900
# [(SQUID_INK, 2004, 1)]
# Actual Time:  979000
# Exit Time:  981000
# [(SQUID_INK, 2004, 1)]
# Actual Time:  979100
# Exit Time:  981100
# [(SQUID_INK, 2005, 1)]
# Actual Time:  979200
# Exit Time:  981200
# [(SQUID_INK, 2006, 1)]
# Actual Time:  979300
# Exit Time:  981300
# [(SQUID_INK, 2008, 1)]
# Actual Time:  979400
# Exit Time:  981400
# [(SQUID_INK, 2006, 1)]
# Actual Time:  979500
# Exit Time:  981500
# [(SQUID_INK, 2008, 1)]
# Actual Time:  979600
# Exit Time:  981600
# [(SQUID_INK, 2005, 1)]
# Actual Time:  979700
# Exit Time:  981700
# [(SQUID_INK, 2006, 1)]
# Actual Time:  979800
# Exit Time:  981800
# [(SQUID_INK, 2007, 1)]
# Actual Time:  979900
# Exit Time:  981900
# []
# Actual Time:  980000
# Exit Time:  982000
# []
# Actual Time:  980100
# Exit Time:  982100
# []
# Actual Time:  980200
# Exit Time:  982200
# []
# Actual Time:  980300
# Exit Time:  982300
# []
# Actual Time:  980400
# Exit Time:  982400
# []
# Actual Time:  980500
# Exit Time:  982500
# []
# Actual Time:  980600
# Exit Time:  982600
# []
# Actual Time:  980700
# Exit Time:  982700
# []
# Actual Time:  980800
# Exit Time:  982800
# []
# Actual Time:  980900
# Exit Time:  982900
# []
# Actual Time:  981000
# Exit Time:  983000
# []
# Actual Time:  981100
# Exit Time:  983100
# []
# Actual Time:  981200
# Exit Time:  983200
# []
# Actual Time:  981300
# Exit Time:  983300
# []
# Actual Time:  981400
# Exit Time:  983400
# []
# Actual Time:  981500
# Exit Time:  983500
# [(SQUID_INK, 1995, 1)]
# Actual Time:  981600
# Exit Time:  983600
# [(SQUID_INK, 1995, 1)]
# Actual Time:  981700
# Exit Time:  983700
# []
# Actual Time:  981800
# Exit Time:  983800
# []
# Actual Time:  981900
# Exit Time:  983900
# []
# Actual Time:  982000
# Exit Time:  984000
# [(SQUID_INK, 1996, 1)]
# Actual Time:  982100
# Exit Time:  984100
# [(SQUID_INK, 1996, 1)]
# Actual Time:  982200
# Exit Time:  984200
# [(SQUID_INK, 1998, 1)]
# Actual Time:  982300
# Exit Time:  984300
# [(SQUID_INK, 1998, 1)]
# Actual Time:  982400
# Exit Time:  984400
# [(SQUID_INK, 1998, 1)]
# Actual Time:  982500
# Exit Time:  984500
# [(SQUID_INK, 1999, 1)]
# Actual Time:  982600
# Exit Time:  984600
# [(SQUID_INK, 2001, 1)]
# Actual Time:  982700
# Exit Time:  984700
# [(SQUID_INK, 2000, 1)]
# Actual Time:  982800
# Exit Time:  984800
# [(SQUID_INK, 2000, 1)]
# Actual Time:  982900
# Exit Time:  984900
# [(SQUID_INK, 2000, 1)]
# Actual Time:  983000
# Exit Time:  985000
# [(SQUID_INK, 2000, 1)]
# Actual Time:  983100
# Exit Time:  985100
# [(SQUID_INK, 2000, 1)]
# Actual Time:  983200
# Exit Time:  985200
# [(SQUID_INK, 2000, 1)]
# Actual Time:  983300
# Exit Time:  985300
# [(SQUID_INK, 2001, 1)]
# Actual Time:  983400
# Exit Time:  985400
# [(SQUID_INK, 2001, 1)]
# Actual Time:  983500
# Exit Time:  985500
# []
# Actual Time:  983600
# Exit Time:  985600
# []
# Actual Time:  983700
# Exit Time:  985700
# []
# Actual Time:  983800
# Exit Time:  985800
# []
# Actual Time:  983900
# Exit Time:  985900
# []
# Actual Time:  984000
# Exit Time:  986000
# []
# Actual Time:  984100
# Exit Time:  986100
# []
# Actual Time:  984200
# Exit Time:  986200
# []
# Actual Time:  984300
# Exit Time:  986300
# []
# Actual Time:  984400
# Exit Time:  986400
# []
# Actual Time:  984500
# Exit Time:  986500
# []
# Actual Time:  984600
# Exit Time:  986600
# []
# Actual Time:  984700
# Exit Time:  986700
# []
# Actual Time:  984800
# Exit Time:  986800
# []
# Actual Time:  984900
# Exit Time:  986900
# [(SQUID_INK, 2006, 1)]
# Actual Time:  985000
# Exit Time:  987000
# [(SQUID_INK, 2004, 1)]
# Actual Time:  985100
# Exit Time:  987100
# [(SQUID_INK, 2004, 1)]
# Actual Time:  985200
# Exit Time:  987200
# [(SQUID_INK, 2003, 1)]
# Actual Time:  985300
# Exit Time:  987300
# [(SQUID_INK, 2000, 1)]
# Actual Time:  985400
# Exit Time:  987400
# [(SQUID_INK, 2001, 1)]
# Actual Time:  985500
# Exit Time:  987500
# [(SQUID_INK, 2001, 1)]
# Actual Time:  985600
# Exit Time:  987600
# [(SQUID_INK, 2003, 1)]
# Actual Time:  985700
# Exit Time:  987700
# [(SQUID_INK, 2001, 1)]
# Actual Time:  985800
# Exit Time:  987800
# [(SQUID_INK, 2001, 1)]
# Actual Time:  985900
# Exit Time:  987900
# [(SQUID_INK, 2002, 1)]
# Actual Time:  986000
# Exit Time:  988000
# []
# Actual Time:  986100
# Exit Time:  988100
# []
# Actual Time:  986200
# Exit Time:  988200
# [(SQUID_INK, 2000, 1)]
# Actual Time:  986300
# Exit Time:  988300
# []
# Actual Time:  986400
# Exit Time:  988400
# []
# Actual Time:  986500
# Exit Time:  988500
# []
# Actual Time:  986600
# Exit Time:  988600
# []
# Actual Time:  986700
# Exit Time:  988700
# []
# Actual Time:  986800
# Exit Time:  988800
# []
# Actual Time:  986900
# Exit Time:  988900
# []
# Actual Time:  987000
# Exit Time:  989000
# []
# Actual Time:  987100
# Exit Time:  989100
# []
# Actual Time:  987200
# Exit Time:  989200
# []
# Actual Time:  987300
# Exit Time:  989300
# []
# Actual Time:  987400
# Exit Time:  989400
# []
# Actual Time:  987500
# Exit Time:  989500
# []
# Actual Time:  987600
# Exit Time:  989600
# []
# Actual Time:  987700
# Exit Time:  989700
# []
# Actual Time:  987800
# Exit Time:  989800
# []
# Actual Time:  987900
# Exit Time:  989900
# []
# Actual Time:  988000
# Exit Time:  990000
# []
# Actual Time:  988100
# Exit Time:  990100
# []
# Actual Time:  988200
# Exit Time:  990200
# []
# Actual Time:  988300
# Exit Time:  990300
# []
# Actual Time:  988400
# Exit Time:  990400
# []
# Actual Time:  988500
# Exit Time:  990500
# []
# Actual Time:  988600
# Exit Time:  990600
# []
# Actual Time:  988700
# Exit Time:  990700
# []
# Actual Time:  988800
# Exit Time:  990800
# []
# Actual Time:  988900
# Exit Time:  990900
# []
# Actual Time:  989000
# Exit Time:  991000
# []
# Actual Time:  989100
# Exit Time:  991100
# []
# Actual Time:  989200
# Exit Time:  991200
# []
# Actual Time:  989300
# Exit Time:  991300
# []
# Actual Time:  989400
# Exit Time:  991400
# []
# Actual Time:  989500
# Exit Time:  991500
# []
# Actual Time:  989600
# Exit Time:  991600
# []
# Actual Time:  989700
# Exit Time:  991700
# []
# Actual Time:  989800
# Exit Time:  991800
# []
# Actual Time:  989900
# Exit Time:  991900
# []
# Actual Time:  990000
# Exit Time:  992000
# []
# Actual Time:  990100
# Exit Time:  992100
# []
# Actual Time:  990200
# Exit Time:  992200
# []
# Actual Time:  990300
# Exit Time:  992300
# []
# Actual Time:  990400
# Exit Time:  992400
# []
# Actual Time:  990500
# Exit Time:  992500
# []
# Actual Time:  990600
# Exit Time:  992600
# []
# Actual Time:  990700
# Exit Time:  992700
# []
# Actual Time:  990800
# Exit Time:  992800
# []
# Actual Time:  990900
# Exit Time:  992900
# []
# Actual Time:  991000
# Exit Time:  993000
# []
# Actual Time:  991100
# Exit Time:  993100
# []
# Actual Time:  991200
# Exit Time:  993200
# []
# Actual Time:  991300
# Exit Time:  993300
# []
# Actual Time:  991400
# Exit Time:  993400
# []
# Actual Time:  991500
# Exit Time:  993500
# []
# Actual Time:  991600
# Exit Time:  993600
# []
# Actual Time:  991700
# Exit Time:  993700
# []
# Actual Time:  991800
# Exit Time:  993800
# []
# Actual Time:  991900
# Exit Time:  993900
# []
# Actual Time:  992000
# Exit Time:  994000
# []
# Actual Time:  992100
# Exit Time:  994100
# []
# Actual Time:  992200
# Exit Time:  994200
# []
# Actual Time:  992300
# Exit Time:  994300
# []
# Actual Time:  992400
# Exit Time:  994400
# []
# Actual Time:  992500
# Exit Time:  994500
# []
# Actual Time:  992600
# Exit Time:  994600
# []
# Actual Time:  992700
# Exit Time:  994700
# []
# Actual Time:  992800
# Exit Time:  994800
# []
# Actual Time:  992900
# Exit Time:  994900
# []
# Actual Time:  993000
# Exit Time:  995000
# []
# Actual Time:  993100
# Exit Time:  995100
# []
# Actual Time:  993200
# Exit Time:  995200
# []
# Actual Time:  993300
# Exit Time:  995300
# []
# Actual Time:  993400
# Exit Time:  995400
# []
# Actual Time:  993500
# Exit Time:  995500
# []
# Actual Time:  993600
# Exit Time:  995600
# []
# Actual Time:  993700
# Exit Time:  995700
# []
# Actual Time:  993800
# Exit Time:  995800
# []
# Actual Time:  993900
# Exit Time:  995900
# []
# Actual Time:  994000
# Exit Time:  996000
# []
# Actual Time:  994100
# Exit Time:  996100
# []
# Actual Time:  994200
# Exit Time:  996200
# []
# Actual Time:  994300
# Exit Time:  996300
# []
# Actual Time:  994400
# Exit Time:  996400
# []
# Actual Time:  994500
# Exit Time:  996500
# []
# Actual Time:  994600
# Exit Time:  996600
# []
# Actual Time:  994700
# Exit Time:  996700
# []
# Actual Time:  994800
# Exit Time:  996800
# []
# Actual Time:  994900
# Exit Time:  996900
# []
# Actual Time:  995000
# Exit Time:  997000
# []
# Actual Time:  995100
# Exit Time:  997100
# []
# Actual Time:  995200
# Exit Time:  997200
# []
# Actual Time:  995300
# Exit Time:  997300
# []
# Actual Time:  995400
# Exit Time:  997400
# []
# Actual Time:  995500
# Exit Time:  997500
# []
# Actual Time:  995600
# Exit Time:  997600
# []
# Actual Time:  995700
# Exit Time:  997700
# []
# Actual Time:  995800
# Exit Time:  997800
# []
# Actual Time:  995900
# Exit Time:  997900
# []
# Actual Time:  996000
# Exit Time:  998000
# []
# Actual Time:  996100
# Exit Time:  998100
# []
# Actual Time:  996200
# Exit Time:  998200
# []
# Actual Time:  996300
# Exit Time:  998300
# []
# Actual Time:  996400
# Exit Time:  998400
# []
# Actual Time:  996500
# Exit Time:  998500
# []
# Actual Time:  996600
# Exit Time:  998600
# []
# Actual Time:  996700
# Exit Time:  998700
# []
# Actual Time:  996800
# Exit Time:  998800
# []
# Actual Time:  996900
# Exit Time:  998900
# []
# Actual Time:  997000
# Exit Time:  999000
# []
# Actual Time:  997100
# Exit Time:  999100
# []
# Actual Time:  997200
# Exit Time:  999200
# []
# Actual Time:  997300
# Exit Time:  999300
# []
# Actual Time:  997400
# Exit Time:  999400
# []
# Actual Time:  997500
# Exit Time:  999500
# []
# Actual Time:  997600
# Exit Time:  999600
# []
# Actual Time:  997700
# Exit Time:  999700
# []
# Actual Time:  997800
# Exit Time:  999800
# []
# Actual Time:  997900
# Exit Time:  999900
# []
# Actual Time:  998000
# Exit Time:  1000000
# [(SQUID_INK, 2001, -1)]
# Actual Time:  998100
# Exit Time:  1000100
# [(SQUID_INK, 2002, -1)]
# Actual Time:  998200
# Exit Time:  1000200
# [(SQUID_INK, 2002, -1)]
# Actual Time:  998300
# Exit Time:  1000300
# [(SQUID_INK, 2000, -1)]
# Actual Time:  998400
# Exit Time:  1000400
# [(SQUID_INK, 2001, -1)]
# Actual Time:  998500
# Exit Time:  1000500
# [(SQUID_INK, 2001, -1)]
# Actual Time:  998600
# Exit Time:  1000600
# [(SQUID_INK, 2001, -1)]
# Actual Time:  998700
# Exit Time:  1000700
# [(SQUID_INK, 2002, -1)]
# Actual Time:  998800
# Exit Time:  1000800
# [(SQUID_INK, 2001, -1)]
# Actual Time:  998900
# Exit Time:  1000900
# []
# Actual Time:  999000
# Exit Time:  1001000
# []
# Actual Time:  999100
# Exit Time:  1001100
# []
# Actual Time:  999200
# Exit Time:  1001200
# []
# Actual Time:  999300
# Exit Time:  1001300
# []
# Actual Time:  999400
# Exit Time:  1001400
# []
# Actual Time:  999500
# Exit Time:  1001500
# [(SQUID_INK, 2003, -1)]
# Actual Time:  999600
# Exit Time:  1001600
# []
# Actual Time:  999700
# Exit Time:  1001700
# [(SQUID_INK, 2005, -1)]
# Actual Time:  999800
# Exit Time:  1001800
# [(SQUID_INK, 2004, -1)]
# Actual Time:  999900
# Exit Time:  1001900
# [(SQUID_INK, 2005, -1)]
# {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': -134.0}

# %%
import matplotlib.pyplot as plt    
product = "SQUID_INK"

resin_metrics = bt.calculate_metrics(product)
print(f"PNL: {bt.pnl}")

print(f"Midpoint Sharpe: {resin_metrics['midpoint_sharpe']:.4f}")
print(f"Spreadcrossing Sharpe: {resin_metrics['spreadcrossing_sharpe']:.4f}")
print(f"Midpoint PnL (bps): {resin_metrics['midpoint_pnl_bps']:.2f}")
print(f"Spreadcrossing PnL (bps): {resin_metrics['spreadcrossing_pnl_bps']:.2f}")

# THIS PART PLOTS SPREADCROSSING_PNL AND MIDPOINT_PNL
spreadcrossing_pnl_history = bt.get_metric("spreadcrossing_pnl", product)
midpoint_pnl_history = bt.get_metric("midpoint_pnl", product)
timestamps = np.unique(bt.market_data["timestamp"])

plt.plot(timestamps, spreadcrossing_pnl_history, label="Spreadcrossing PnL", color="blue")
plt.plot(timestamps, midpoint_pnl_history, label="Midpoint PnL", color="orange")
plt.xlabel("Timestamp")
plt.ylabel("PnL")
plt.title("Spread Crossing vs Midpoint PnL Over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# PNL: {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': -134.0}
# Midpoint Sharpe: -0.0435
# Spreadcrossing Sharpe: -0.0462
# Midpoint PnL (bps): -0.01
# Spreadcrossing PnL (bps): -0.01

# %% [markdown]
# You can copy paste everything, except for the Trader algo, which should be whatever algo you wish to backtest.
