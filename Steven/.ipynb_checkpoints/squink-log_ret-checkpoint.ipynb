# %% [markdown]
# # Guide on how to use the backtester

# %%
# Ensure the project root is in PATH.
import sys
sys.path.append("../")
# All imports of our code are relative to the project root.

from backtester.backtester import Backtester
from backtester.datamodel import TradingState, OrderDepth, Order, Listing

import numpy as np
import pandas as pd
import sys
import os

# %% [markdown]
# This is the implementation of our trader

# %%
class Trader:

    kelp_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    resin_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss"
    ])

    squink_df = pd.DataFrame(columns=[
        "timestamp", "product",
        "bid_price_1", "bid_volume_1", "bid_price_2", "bid_volume_2", "bid_price_3", "bid_volume_3",
        "ask_price_1", "ask_volume_1", "ask_price_2", "ask_volume_2", "ask_price_3", "ask_volume_3",
        "mid_price", "profit_and_loss", "log_return"
    ])
    # “If none of the bots trade on an outstanding player quote, the quote is automatically cancelled at the end of the iteration.”

    def update_df(df, product, state, orders, order_depth):
        buy_orders = sorted(order_depth.buy_orders.items(), key=lambda x: -x[0])
        sell_orders = sorted(order_depth.sell_orders.items(), key=lambda x: x[0])

        bid_levels = buy_orders[:3] + [(None, None)] * (3 - len(buy_orders))
        ask_levels = sell_orders[:3] + [(None, None)] * (3 - len(sell_orders))

        if bid_levels[0][0] is not None and ask_levels[0][0] is not None:
            mid_price = (bid_levels[0][0] + ask_levels[0][0]) / 2
        else:
            mid_price = None
        if len(df) == 0:
            log_return = 0
        else:
            log_return = np.log(mid_price/df.mid_price.iloc[-1])
            
        row = {
            "timestamp": state.timestamp,
            "product": product,
            "bid_price_1": bid_levels[0][0], "bid_volume_1": bid_levels[0][1],
            "bid_price_2": bid_levels[1][0], "bid_volume_2": bid_levels[1][1],
            "bid_price_3": bid_levels[2][0], "bid_volume_3": bid_levels[2][1],
            "ask_price_1": ask_levels[0][0], "ask_volume_1": ask_levels[0][1],
            "ask_price_2": ask_levels[1][0], "ask_volume_2": ask_levels[1][1],
            "ask_price_3": ask_levels[2][0], "ask_volume_3": ask_levels[2][1],
            "mid_price": mid_price, "log_return": log_return
        }

        df.loc[len(df)] = row



    def run(self, state: TradingState):
        # Only method required. It takes all buy and sell orders for all symbols as an input, and outputs a list of orders to be sent

        result = {}
        for product in state.order_depths:
            order_depth: OrderDepth = state.order_depths[product]
            orders: List[Order] = []
            if product == "SQUID_INK":
                # Check the rolling z score. If it is > 4, we sell,
                squink_position = state.position.get(product, 0)
                Trader.update_df(Trader.squink_df, product, state, orders, order_depth) 
                
                if len(order_depth.sell_orders) != 0 and len(order_depth.buy_orders) != 0:
                    best_ask, best_ask_amount = list(order_depth.sell_orders.items())[0]
                    best_bid, best_bid_amount = list(order_depth.buy_orders.items())[0]
                    mid_price = (best_ask + best_bid)/2
                    rolling_window = 150
                    if len(self.squink_df) > rolling_window:
                        log_return = np.log(mid_price/self.squink_df.mid_price.iloc[-2])

                        z_score = (log_return - self.squink_df.log_return.rolling(rolling_window).mean().iloc[-1])/self.squink_df.log_return.rolling(rolling_window).std().iloc[-1]
                        # Now that I have the Z-Score, I want to implement an edge model for entry
                        
                        edge_0 = 3
                        if abs(z_score) > edge_0:
                            target_position = min(int((np.abs(z_score) - edge_0) * 10), 30)
                        else:
                            target_position = 0
                        # Trying simple linear scheme right now to enter, next is to consider exit
                        print(f"Squink_position: {squink_position}")
                        print(f"z_score: {z_score}, target_position: {target_position}")
                        # Entry
                        
                        if z_score <= -edge_0:
                            print("A")
                            target_position = max(target_position, squink_position)
                            size_needed = target_position - squink_position
                            if size_needed < 0:
                                pass
                            else:
                                orders.append(Order(product, best_ask, size_needed))
                                    
                         
                        elif z_score >= edge_0:
                            print("C")
                            target_position = min(-target_position, squink_position)
                            size_needed = target_position - squink_position
                            if size_needed > 0:
                                pass
                            else:
                                orders.append(Order(product, best_bid, size_needed))

                        # Now what if it is between?

                        else:
                            if squink_position > 0:
                                if z_score > 0:
                                    target_position = 0
                                    size_needed = target_position - squink_position
                                    orders.append(Order(product, best_bid, size_needed))
                                else:
                                    exit_position = min(squink_position, int(-15*z_score))
                                    trades_needed = exit_position - squink_position
                                    orders.append(Order(product, best_bid, -trades_needed))


                            if squink_position < 0:
                                if z_score < 0:
                                    target_position = 0
                                    size_needed = target_position - squink_position
                                    orders.append(Order(product, best_ask, size_needed))
                                else:
                                    exit_position = min(squink_position, int(15*z_score))
                                    trades_needed = exit_position - squink_position
                                    orders.append(Order(product, best_ask, trades_needed)) 
                      


                        
    
                        

                result[product] = orders
                print(orders)

        traderData = "SAMPLE"  # String value holding Trader state data required. It will be delivered as TradingState.traderData on next execution.

        conversions = 1
        return result, conversions, traderData

# %% [markdown]
# Copy paste these below lines whenever you want to access the historical data. These have datatype `pd.Dataframe`.
#
# If you want all 3 days combined into 1, then copy the code for `market_data_all3days` and `trades_all3days`. You can't just `pd.concat()` them all because the backtester doesn't consider day.

# %%
market_data_day_0 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_0.csv"), sep=";")
market_data_day_neg1 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_-1.csv"), sep=";")
market_data_day_neg2 = pd.read_csv(os.path.join("..", "data", "round1", "prices_round_1_day_-2.csv"), sep=";")

trades_day_0 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_0.csv"), sep=";")
trades_day_neg1 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_-1.csv"), sep=";")
trades_day_neg2 = pd.read_csv(os.path.join("..", "data", "round1", "trades_round_1_day_-2.csv"), sep=";")


# concatenates multiple days of historical data into 1.
# drops day column and replaces it with continuous timestamps.
# i.e. day -1 timestamp 0 becomes just timestamp 1,000,000
def concatenate_historical_data(data: list[pd.DataFrame]) -> pd.DataFrame:
    output = data[0]

    for i in range(1, len(data), 1):
        timeshift = output.iloc[-1]["timestamp"] + 100  # 100 for next day
        next_day_copy = data[i].copy()
        next_day_copy["timestamp"] += timeshift

        output = pd.concat([output, next_day_copy])

    return output

market_data_all3days = concatenate_historical_data([market_data_day_neg2, market_data_day_neg1, market_data_day_0])
trades_all3days = concatenate_historical_data([trades_day_neg2, trades_day_neg1, trades_day_0])

# %% [markdown]
# Lets run the backtester

# %%
# 1. Define the listings.
listings = {
    "KELP": Listing(symbol="KELP", product="KELP", denomination="SEASHELLS"),
    "RAINFOREST_RESIN": Listing(symbol="RAINFOREST_RESIN", product="RAINFOREST_RESIN", denomination="SEASHELLS"),
    "SQUID_INK": Listing(symbol="SQUID_INK", product="SQUID_INK", denomination="SEASHELLS"),
}

# 2. Define the position limits.
position_limit = {
    "KELP": 50,
    "RAINFOREST_RESIN": 50,
    "SQUID_INK": 50,
}


# 3. Define fair value evaluation functions. This is used to determine what our PNL is at times throughout execution when our net position is not 0.
def calc_rainforest_resin_fair(order_depth: OrderDepth) -> float:
    return 10000


fair_value_evaluator = {
    # omitting dictionary entries for KELP, SQUID_INK, so that they use default behaviour: fair_price = (best_bid+best_ask)/2
    "RAINFOREST_RESIN": calc_rainforest_resin_fair,
}


# 4. Market data and trade history files.
# These already exist, look at the previous jupyter cell.

# 5. Instantiate trader object
trader = Trader()
bt = Backtester(trader, listings, position_limit, fair_value_evaluator, market_data_day_neg2, trades_day_neg2, output_log_filename="steven.log")


bt.run()

print(bt.pnl)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Squink_position: 0
# z_score: 0.0026913888605738685, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39821236073012756, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3999638254295514, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8090453964612883, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8054275841909136, target_position: 0
# []
# Squink_position: 0
# z_score: 0.41401873826661495, target_position: 0
# []
# Squink_position: 0
# z_score: 1.9936493698651805, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1926873907805784, target_position: 0
# []
# Squink_position: 0
# z_score: 0.419762673659872, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8085247600630173, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2035320246812484, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4199946828167298, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39000790105872957, target_position: 0
# []
# Squink_position: 0
# z_score: -0.38720471356646025, target_position: 0
# []
# Squink_position: 0
# z_score: -1.629973079418865, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8408744810028035, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4285132189277754, target_position: 0
# []
# Squink_position: 0
# z_score: 0.016467396262454855, target_position: 0
# []
# Squink_position: 0
# z_score: -0.398981221207958, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03394968572437116, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3986117414462888, target_position: 0
# []
# Squink_position: 0
# z_score: 0.037170082823543504, target_position: 0
# []
# Squink_position: 0
# z_score: 0.45884202197047996, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8770234452099607, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4506550408565336, target_position: 0
# []
# Squink_position: 0
# z_score: 0.022954151084520518, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8289372397467256, target_position: 0
# []
# Squink_position: 0
# z_score: -0.398863946410881, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8875770173204963, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8192726408769675, target_position: 0
# []
# Squink_position: 0
# z_score: 0.46654623859684496, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3891875404562071, target_position: 0
# []
# Squink_position: 0
# z_score: 0.028853384771996112, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2562456706261864, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8997763362066654, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8175705375950195, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4732606318406295, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3147044684307923, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3886654415524315, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4060175386433147, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3335302211332671, target_position: 0
# []
# Squink_position: 0
# z_score: -1.275585544457809, target_position: 0
# []
# Squink_position: 0
# z_score: -0.40038348681521974, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8967062735095602, target_position: 0
# []
# Squink_position: 0
# z_score: -0.41275584185663594, target_position: 0
# []
# Squink_position: 0
# z_score: 0.45921346042799255, target_position: 0
# []
# Squink_position: 0
# z_score: 0.890202499700709, target_position: 0
# []
# Squink_position: 0
# z_score: 0.005889441849780887, target_position: 0
# []
# Squink_position: 0
# z_score: 0.017849693041442394, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01193361545310016, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4397098163367828, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8769514636459883, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3616942069622373, target_position: 0
# []
# Squink_position: 0
# z_score: 0.017897119880880483, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3070699873763627, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8495152918083861, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3658378247643679, target_position: 0
# []
# Squink_position: 0
# z_score: 0.921514928990948, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0060997121441482395, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3535704649879103, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3411888473902467, target_position: 0
# []
# Squink_position: 0
# z_score: 0.021149969685181434, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8756218377938995, target_position: 0
# []
# Squink_position: 0
# z_score: 0.942250300560981, target_position: 0
# []
# Squink_position: 0
# z_score: -1.311612910792989, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4117733021885788, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3021765024267073, target_position: 0
# []
# Squink_position: 0
# z_score: -0.38856846207344076, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5259180949497096, target_position: 0
# []
# Squink_position: 0
# z_score: 0.06384009338585224, target_position: 0
# []
# Squink_position: 0
# z_score: 0.049494780639924074, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4224257682742223, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4142311872017819, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3316683463067027, target_position: 0
# []
# Squink_position: 0
# z_score: 3.6616781336575195, target_position: 6
# C
# [(SQUID_INK, 1995, -6)]
# Squink_position: -1
# z_score: 0.05402945100645552, target_position: 0
# [(SQUID_INK, 1997, 0)]
# Squink_position: -1
# z_score: -0.3940753010178248, target_position: 0
# [(SQUID_INK, 1996, 1)]
# Squink_position: 0
# z_score: 0.4998725476272717, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05746276941108543, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8418674926200141, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9619401953145138, target_position: 0
# []
# Squink_position: 0
# z_score: -0.40319262203807427, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3943218847132508, target_position: 0
# []
# Squink_position: 0
# z_score: 0.48719782036210896, target_position: 0
# []
# Squink_position: 0
# z_score: -0.85594883125466, target_position: 0
# []
# Squink_position: 0
# z_score: -0.40941587109918487, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5079510594376484, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05467855853016397, target_position: 0
# []
# Squink_position: 0
# z_score: -0.40204392380186776, target_position: 0
# []
# Squink_position: 0
# z_score: -1.308743997525998, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5068947798086539, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05771833394994469, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3001630409876688, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9792224849100515, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4025027263911811, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9678225469015397, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7570269433785322, target_position: 0
# []
# Squink_position: 0
# z_score: -1.290328411010415, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07556767017046725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.37929563168834945, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5304434609296997, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4311153976312139, target_position: 0
# []
# Squink_position: 0
# z_score: -1.709233902463891, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4333123661069915, target_position: 0
# []
# Squink_position: 0
# z_score: 2.2724323327969698, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8083682979715551, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2432178385975363, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3815824749022592, target_position: 0
# []
# Squink_position: 0
# z_score: 0.06407228701773746, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2333139190828157, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3727169507192851, target_position: 0
# []
# Squink_position: 0
# z_score: -0.36203690365431607, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3656147585412147, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5011026858704702, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0635940741430689, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3656094451760067, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9270357296822026, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7751158505878446, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9079797842310011, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8011049211145823, target_position: 0
# []
# Squink_position: 0
# z_score: -1.6431973206355268, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3612692231772427, target_position: 0
# []
# Squink_position: 0
# z_score: -0.799209128139195, target_position: 0
# []
# Squink_position: 0
# z_score: 0.919157355766718, target_position: 0
# []
# Squink_position: 0
# z_score: -0.37302543504182195, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9175838676345768, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3803854156049525, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9217237098769164, target_position: 0
# []
# Squink_position: 0
# z_score: 0.48216805275329944, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8076869978065848, target_position: 0
# []
# Squink_position: 0
# z_score: 0.910715203848639, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8379923026985971, target_position: 0
# []
# Squink_position: 0
# z_score: 1.781772186485204, target_position: 0
# []
# Squink_position: 0
# z_score: -2.1566415108375834, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8890312997949629, target_position: 0
# []
# Squink_position: 0
# z_score: 0.023275944928368333, target_position: 0
# []
# Squink_position: 0
# z_score: -0.40315987105433326, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9159677050945572, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9045823052369866, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8807541674186995, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8695036488713178, target_position: 0
# []
# Squink_position: 0
# z_score: 0.036085538620281805, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9353691318062406, target_position: 0
# []
# Squink_position: 0
# z_score: 0.006167993164766041, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3624722676857712, target_position: 0
# []
# Squink_position: 0
# z_score: -1.343929257265094, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4936547225955639, target_position: 0
# []
# Squink_position: 0
# z_score: -0.42026292601832693, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8758491887858733, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4060470339678193, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3192128973599575, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39485692151474405, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3889897983264566, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9862166825928261, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8632043334855065, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39502660992776645, target_position: 0
# []
# Squink_position: 0
# z_score: 0.08463282639013785, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07570404137478547, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8629134390929356, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39300176183731306, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07308641785336079, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5510318966682289, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8105422334469645, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5484634131611846, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0636066274600041, target_position: 0
# []
# Squink_position: 0
# z_score: 0.070193335404141, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07344779187861782, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07344779187861782, target_position: 0
# []
# Squink_position: 0
# z_score: 1.021352944986045, target_position: 0
# []
# Squink_position: 0
# z_score: 0.06366929587571422, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4764066861852305, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05057534336309109, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5255970515037243, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0002224985166446, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5251837963783574, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9898762225912782, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9763307923934446, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8823601855151417, target_position: 0
# []
# Squink_position: 0
# z_score: -3.125858606902803, target_position: 1
# A
# [(SQUID_INK, 1990, 1)]
# Squink_position: 1
# z_score: 0.9354484268092719, target_position: 0
# [(SQUID_INK, 1989, -1)]
# Squink_position: 0
# z_score: 0.9299720660163655, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9184291856599536, target_position: 0
# []
# Squink_position: 0
# z_score: 0.017990709579002787, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7719696902463893, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9175541101102868, target_position: 0
# []
# Squink_position: 0
# z_score: 0.46096364858143496, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4310873329697437, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9220508002645987, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7882282292013234, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8857301151824672, target_position: 0
# []
# Squink_position: 0
# z_score: 0.44952674593459374, target_position: 0
# []
# Squink_position: 0
# z_score: -2.2015299418954677, target_position: 0
# []
# Squink_position: 0
# z_score: 0.44522843567498865, target_position: 0
# []
# Squink_position: 0
# z_score: 0.44895266620275287, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8810601481334535, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8764024173028397, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8651971049152664, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01764805558775444, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2912820898993105, target_position: 0
# []
# Squink_position: 0
# z_score: 0.026332480125839254, target_position: 0
# []
# Squink_position: 0
# z_score: 0.459731302529122, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4516564545288155, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8566109683792341, target_position: 0
# []
# Squink_position: 0
# z_score: 2.1826342456274714, target_position: 0
# []
# Squink_position: 0
# z_score: 0.002908965848042738, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7246059375120268, target_position: 0
# []
# Squink_position: 0
# z_score: -0.84703871253366, target_position: 0
# []
# Squink_position: 0
# z_score: 0.02905656416982997, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8933949691571607, target_position: 0
# []
# Squink_position: 0
# z_score: -0.41974316613312984, target_position: 0
# []
# Squink_position: 0
# z_score: 0.44527309826657135, target_position: 0
# []
# Squink_position: 0
# z_score: 0.005856680858698405, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8730812673554872, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8619182008594543, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7474357568322187, target_position: 0
# []
# Squink_position: 0
# z_score: -0.43090964163928797, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8762567812344008, target_position: 0
# []
# Squink_position: 0
# z_score: -0.008828446167548321, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8809737552701312, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8732814439310312, target_position: 0
# []
# Squink_position: 0
# z_score: -0.430674204983244, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4564981152878615, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4504691635261215, target_position: 0
# []
# Squink_position: 0
# z_score: 8.24177061870197e-15, target_position: 0
# []
# Squink_position: 0
# z_score: 0.48560212405858594, target_position: 0
# []
# Squink_position: 0
# z_score: 0.48201529680319416, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015448399700845116, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9375381630203381, target_position: 0
# []
# Squink_position: 0
# z_score: -2.246821379115124, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4741192548853037, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9296581822064133, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015187238832824534, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8850458673910576, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9408915321070942, target_position: 0
# []
# Squink_position: 0
# z_score: 0.02134791771668906, target_position: 0
# []
# Squink_position: 0
# z_score: 0.47299397448106223, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01830760730760777, target_position: 0
# []
# Squink_position: 0
# z_score: -0.43644984234928547, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4365583570608864, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4452222968328631, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01842516955594813, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8951784708746382, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015417961361194225, target_position: 0
# []
# Squink_position: 0
# z_score: -1.353780613821378, target_position: 0
# []
# Squink_position: 0
# z_score: 1.394582695818393, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9352382264870845, target_position: 0
# []
# Squink_position: 0
# z_score: 0.006178730156245131, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9275170946768903, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8261936467683948, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9250714359225107, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009190429246969823, target_position: 0
# []
# Squink_position: 0
# z_score: 0.018494453683552597, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9330843794401887, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009387235066164203, target_position: 0
# []
# Squink_position: 0
# z_score: 0.025498693638707225, target_position: 0
# []
# Squink_position: 0
# z_score: 0.019184928942149133, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009662035191958587, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01945698091276954, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4638126365944121, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4374914003311217, target_position: 0
# []
# Squink_position: 0
# z_score: 2.4183375438696673, target_position: 0
# []
# Squink_position: 0
# z_score: 0.48966260129741257, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4159341070032014, target_position: 0
# []
# Squink_position: 0
# z_score: -0.45530680697342774, target_position: 0
# []
# Squink_position: 0
# z_score: -2.308757184921076, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3577171145353144, target_position: 0
# []
# Squink_position: 0
# z_score: 2.332551941290353, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4152956105658542, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4072246318126053, target_position: 0
# []
# Squink_position: 0
# z_score: -0.41123804950743537, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9792383563563106, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8989942602895324, target_position: 0
# []
# Squink_position: 0
# z_score: -1.361669010637405, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05004705193283118, target_position: 0
# []
# Squink_position: 0
# z_score: 0.513713270511801, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05018206793495416, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9807211277597551, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9802078725913923, target_position: 0
# []
# Squink_position: 0
# z_score: 0.043796569605701725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.43034328615098677, target_position: 0
# []
# Squink_position: 0
# z_score: 0.047181281825987846, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8224453848404432, target_position: 0
# []
# Squink_position: 0
# z_score: 0.5376494775525232, target_position: 0
# []
# Squink_position: 0
# z_score: 1.004480583117346, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04820208409331422, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04820208409331422, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0014009497779983, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04499882319755644, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0106676867418172, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4699050843312569, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9758438684891204, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4351871213440808, target_position: 0
# []
# Squink_position: 0
# z_score: 0.012729163480523865, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4016099013447219, target_position: 0
# []
# Squink_position: 0
# z_score: 0.012738574168467933, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0032077737978451087, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4843728480353975, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9533535046149039, target_position: 0
# []
# Squink_position: 0
# z_score: -0.012840493544209186, target_position: 0
# []
# Squink_position: 0
# z_score: -1.9070133497502206, target_position: 0
# []
# Squink_position: 0
# z_score: -0.01279403031005795, target_position: 0
# []
# Squink_position: 0
# z_score: -0.49239333321466006, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4369720933738774, target_position: 0
# []
# Squink_position: 0
# z_score: 4.969683744172219e-15, target_position: 0
# []
# Squink_position: 0
# z_score: -0.006401513285128092, target_position: 0
# []
# Squink_position: 0
# z_score: 2.776056842981396, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8063206029789267, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9539098213226189, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9544043216783299, target_position: 0
# []
# Squink_position: 0
# z_score: -0.49429126869460643, target_position: 0
# []
# Squink_position: 0
# z_score: -1.843064424837991, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8850211118841208, target_position: 0
# []
# Squink_position: 0
# z_score: -0.03684417369215387, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3289033781123563, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4109713996355263, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3978239349328079, target_position: 0
# []
# Squink_position: 0
# z_score: -0.036373861820210816, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7482377317942315, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9334023247556593, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8533939963828823, target_position: 0
# []
# Squink_position: 0
# z_score: -0.033052969818551506, target_position: 0
# []
# Squink_position: 0
# z_score: -0.033052969818551506, target_position: 0
# []
# Squink_position: 0
# z_score: 0.862266879750419, target_position: 0
# []
# Squink_position: 0
# z_score: -2.649760710433378, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8634678288214269, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8630398804423066, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7392435556997243, target_position: 0
# []
# Squink_position: 0
# z_score: -0.42250355489476593, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4483618402472597, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1825553021691733e-15, target_position: 0
# []
# Squink_position: 0
# z_score: 0.006090520650860738, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9196629581109114, target_position: 0
# []
# Squink_position: 0
# z_score: -3.0694824728695926, target_position: 0
# A
# [(SQUID_INK, 1989, 0)]
# Squink_position: 0
# z_score: 1.7720982488173282, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3213682719607822, target_position: 0
# []
# Squink_position: 0
# z_score: -0.43448233341556874, target_position: 0
# []
# Squink_position: 0
# z_score: 0.875941077503542, target_position: 0
# []
# Squink_position: 0
# z_score: -0.870111609296543, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3359793769925985, target_position: 0
# []
# Squink_position: 0
# z_score: 0.017684031382956173, target_position: 0
# []
# Squink_position: 0
# z_score: 0.020643478520679444, target_position: 0
# []
# Squink_position: 0
# z_score: 0.00599990115274501, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8837167602753092, target_position: 0
# []
# Squink_position: 0
# z_score: 0.017977820186834553, target_position: 0
# []
# Squink_position: 0
# z_score: 0.47167861040056486, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3524495715662346, target_position: 0
# []
# Squink_position: 0
# z_score: -2.1988973709680275, target_position: 0
# []
# Squink_position: 0
# z_score: 1.326472520730159, target_position: 0
# []
# Squink_position: 0
# z_score: -0.002951211615674735, target_position: 0
# []
# Squink_position: 0
# z_score: -0.44238898131992715, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4423889813196751, target_position: 0
# []
# Squink_position: 0
# z_score: 0.879770892414893, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8856575498735726, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4574847695936542, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3201151205748711, target_position: 0
# []
# Squink_position: 0
# z_score: 0.006010771550097214, target_position: 0
# []
# Squink_position: 0
# z_score: -3.0464461051785463, target_position: 0
# A
# [(SQUID_INK, 1990, 0)]
# Squink_position: 0
# z_score: -2.1256662773997874, target_position: 0
# []
# Squink_position: 0
# z_score: -1.6670066463899482, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9002893876748739, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04566393553720634, target_position: 0
# []
# Squink_position: 0
# z_score: 1.315733390532121, target_position: 0
# []
# Squink_position: 0
# z_score: -1.235485165614517, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7092393579270773, target_position: 0
# []
# Squink_position: 0
# z_score: -4.322089303153036, target_position: 13
# A
# [(SQUID_INK, 1982, 13)]
# Squink_position: 8
# z_score: 3.472208773247038, target_position: 4
# C
# [(SQUID_INK, 1984, -12)]
# Squink_position: -4
# z_score: -1.097645692739653, target_position: 0
# [(SQUID_INK, 1985, 4)]
# Squink_position: -1
# z_score: 1.1757928780397262, target_position: 0
# [(SQUID_INK, 1987, 0)]
# Squink_position: -1
# z_score: 0.40988679690699237, target_position: 0
# [(SQUID_INK, 1987, 0)]
# Squink_position: -1
# z_score: 1.1526794387968968, target_position: 0
# [(SQUID_INK, 1989, 0)]
# Squink_position: -1
# z_score: 1.5060876184066097, target_position: 0
# [(SQUID_INK, 1991, 0)]
# Squink_position: -1
# z_score: -0.7368585575419457, target_position: 0
# [(SQUID_INK, 1989, 1)]
# Squink_position: 0
# z_score: 0.014986892169361301, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1270641233274166, target_position: 0
# []
# Squink_position: 0
# z_score: 0.38047064070443093, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009945652108564938, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3606041479842614, target_position: 0
# []
# Squink_position: 0
# z_score: -0.35378047211574615, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7424403210438215, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1065575241638579, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1463759721598694, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4613609862823973, target_position: 0
# []
# Squink_position: 0
# z_score: 0.024876676718166034, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4015133013340106, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7147149670159554, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8678965117047288, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7097950729804906, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7067832362061518, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7037821012706522, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7589055025874377, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7522015406897146, target_position: 0
# []
# Squink_position: 0
# z_score: -0.34967134571581443, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7442744631872978, target_position: 0
# []
# Squink_position: 0
# z_score: -0.35995430918320126, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3515740569702117, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7546306845473121, target_position: 0
# []
# Squink_position: 0
# z_score: 0.38312307163347475, target_position: 0
# []
# Squink_position: 0
# z_score: 1.464539230654911, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4645392306548173, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4518609209780668, target_position: 0
# []
# Squink_position: 0
# z_score: -0.004854497726022928, target_position: 0
# []
# Squink_position: 0
# z_score: -0.004854497726022928, target_position: 0
# []
# Squink_position: 0
# z_score: -0.36209499633402853, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3643616483141125, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7223159773268197, target_position: 0
# []
# Squink_position: 0
# z_score: 0.715863133555021, target_position: 0
# []
# Squink_position: 0
# z_score: -0.009676288355949383, target_position: 0
# []
# Squink_position: 0
# z_score: -0.009676288355949383, target_position: 0
# []
# Squink_position: 0
# z_score: -0.01210255607625519, target_position: 0
# []
# Squink_position: 0
# z_score: -0.01945139163818096, target_position: 0
# []
# Squink_position: 0
# z_score: -0.007371254793566103, target_position: 0
# []
# Squink_position: 0
# z_score: -0.37091846233799947, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7438242445631272, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0895460676656563, target_position: 0
# []
# Squink_position: 0
# z_score: -0.027341366246797952, target_position: 0
# []
# Squink_position: 0
# z_score: -0.034967073198888546, target_position: 0
# []
# Squink_position: 0
# z_score: -1.145500699150113, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1013048919238533, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8712701822314788, target_position: 0
# []
# Squink_position: 0
# z_score: 0.35166824680971936, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7229025604381142, target_position: 0
# []
# Squink_position: 0
# z_score: -0.024831321154704107, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7733893714637781, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3430223610098314, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8038405732455352, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7699297508590883, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3363234529841666, target_position: 0
# []
# Squink_position: 0
# z_score: 0.339142279726596, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39554626427425177, target_position: 0
# []
# Squink_position: 0
# z_score: 0.33655015543462746, target_position: 0
# []
# Squink_position: 0
# z_score: 0.698746294500453, target_position: 0
# []
# Squink_position: 0
# z_score: -1.866401117109275, target_position: 0
# []
# Squink_position: 0
# z_score: -0.031840489966426626, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7015804560106238, target_position: 0
# []
# Squink_position: 0
# z_score: -0.03182484798261564, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6951902269037067, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3956349052068627, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6970977946063143, target_position: 0
# []
# Squink_position: 0
# z_score: -0.029336178474962726, target_position: 0
# []
# Squink_position: 0
# z_score: -0.022079694610289444, target_position: 0
# []
# Squink_position: 0
# z_score: -0.01719845801480716, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3769628335519193, target_position: 0
# []
# Squink_position: 0
# z_score: -0.007395063896221703, target_position: 0
# []
# Squink_position: 0
# z_score: -0.38342294748230515, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7483789270579823, target_position: 0
# []
# Squink_position: 0
# z_score: -0.007414296709428978, target_position: 0
# []
# Squink_position: 0
# z_score: -0.004944449863118884, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7367230296039666, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3731765391348158, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1160013045804391, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4671105912484803, target_position: 0
# []
# Squink_position: 0
# z_score: -1.469305254943784, target_position: 0
# []
# Squink_position: 0
# z_score: -2.5180853295422763, target_position: 0
# []
# Squink_position: 0
# z_score: 1.7800668385655662, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7026141925752086, target_position: 0
# []
# Squink_position: 0
# z_score: -2.1186701633602083, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3851275434082482, target_position: 0
# []
# Squink_position: 0
# z_score: 0.378298864220354, target_position: 0
# []
# Squink_position: 0
# z_score: 0.014377633189818165, target_position: 0
# []
# Squink_position: 0
# z_score: 0.011987676459472933, target_position: 0
# []
# Squink_position: 0
# z_score: 0.00241539882718942, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0842683923701344, target_position: 0
# []
# Squink_position: 0
# z_score: -1.072843888806948, target_position: 0
# []
# Squink_position: 0
# z_score: -0.34463846934351716, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7363468467590596, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7254713917215604, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3612354613988384, target_position: 0
# []
# Squink_position: 0
# z_score: 1.088908799192681, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3576317158573403, target_position: 0
# []
# Squink_position: 0
# z_score: -1.9032368557652502e-15, target_position: 0
# []
# Squink_position: 0
# z_score: 1.4318004340718782, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3479740542986547, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7076919142231537, target_position: 0
# []
# Squink_position: 0
# z_score: 2.117919065691633, target_position: 0
# []
# Squink_position: 0
# z_score: 1.032837172387829, target_position: 0
# []
# Squink_position: 0
# z_score: 2.069492133142795, target_position: 0
# []
# Squink_position: 0
# z_score: -0.061895104090784844, target_position: 0
# []
# Squink_position: 0
# z_score: 0.642136201899957, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6387283131056337, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1244267787045943, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8013797889924217, target_position: 0
# []
# Squink_position: 0
# z_score: 0.30134767960580866, target_position: 0
# []
# Squink_position: 0
# z_score: 0.28863581570668334, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6545579184015597, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6580039134544409, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7797758199626381, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6594791330211416, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06510317858677583, target_position: 0
# []
# Squink_position: 0
# z_score: -0.05805276061986237, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6594665498849875, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1341240380484476, target_position: 0
# []
# Squink_position: 0
# z_score: -2.1658181777696823, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3075943398830692, target_position: 0
# []
# Squink_position: 0
# z_score: -0.04745227631376305, target_position: 0
# []
# Squink_position: 0
# z_score: -0.0450882725707154, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6687318029197002, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3019014258303363, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6650567890704059, target_position: 0
# []
# Squink_position: 0
# z_score: -0.41291650903953653, target_position: 0
# []
# Squink_position: 0
# z_score: -1.124427932655718, target_position: 0
# []
# Squink_position: 0
# z_score: -0.045590012764949187, target_position: 0
# []
# Squink_position: 0
# z_score: 0.31622890212721416, target_position: 0
# []
# Squink_position: 0
# z_score: -0.048136456320443284, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3119530604526925, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4146065553214763, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3057746302482973, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0238207846009006, target_position: 0
# []
# Squink_position: 0
# z_score: -0.46518971387614527, target_position: 0
# []
# Squink_position: 0
# z_score: 0.2701506722091397, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8469194030093492, target_position: 0
# []
# Squink_position: 0
# z_score: -0.0956400189628691, target_position: 0
# []
# Squink_position: 0
# z_score: -0.08837866300436137, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6554235898446358, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6637825320177763, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9391546828058662, target_position: 0
# []
# Squink_position: 0
# z_score: -0.10800860834337114, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9631121002425833, target_position: 0
# []
# Squink_position: 0
# z_score: 0.32181464470226556, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7453558037716796, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5261651863970662, target_position: 0
# []
# Squink_position: 0
# z_score: 1.6165063342194768, target_position: 0
# []
# Squink_position: 0
# z_score: -0.10357274960895144, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7483229703535913, target_position: 0
# []
# Squink_position: 0
# z_score: -0.52827499676134, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5223368778651942, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3350472777826578, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5250510141958298, target_position: 0
# []
# Squink_position: 0
# z_score: 1.178840701963289, target_position: 0
# []
# Squink_position: 0
# z_score: -1.799689253985857, target_position: 0
# []
# Squink_position: 0
# z_score: 0.31605213664785115, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3760120411310912, target_position: 0
# []
# Squink_position: 0
# z_score: -1.386510488040376, target_position: 0
# []
# Squink_position: 0
# z_score: 1.5949332361811481, target_position: 0
# []
# Squink_position: 0
# z_score: -0.948649150543073, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7796462604704226, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3446493906096049, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1828959175124585, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9503935793118476, target_position: 0
# []
# Squink_position: 0
# z_score: -1.370525699358135, target_position: 0
# []
# Squink_position: 0
# z_score: 2.7974879094665273, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7323747571073889, target_position: 0
# []
# Squink_position: 0
# z_score: -0.09093050345676484, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7321666754040962, target_position: 0
# []
# Squink_position: 0
# z_score: 1.5293619026500456, target_position: 0
# []
# Squink_position: 0
# z_score: -0.10671865962107734, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5074499291402413, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3103106031309411, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9048416189661241, target_position: 0
# []
# Squink_position: 0
# z_score: 0.729393449455497, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7336424725731603, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07759217471635181, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4887162619214385, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1514498578536096, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8996461283031042, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07167612080802971, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06627371376259703, target_position: 0
# []
# Squink_position: 0
# z_score: 0.752522127678875, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07164221751667027, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7452304155001979, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07699039088228216, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07699039088228216, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07981333866815662, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4949555150544977, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3364049584299764, target_position: 0
# []
# Squink_position: 0
# z_score: 0.743137105199988, target_position: 0
# []
# Squink_position: 0
# z_score: -2.4917773722735332, target_position: 0
# []
# Squink_position: 0
# z_score: 0.33065237206494197, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7419295887005053, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1397061925664331, target_position: 0
# []
# Squink_position: 0
# z_score: -2.4972351600491356, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1301093903581605, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4777156172258725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.880423392585747, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07273929404236211, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06000977948606203, target_position: 0
# []
# Squink_position: 0
# z_score: -0.471729686837138, target_position: 0
# []
# Squink_position: 0
# z_score: 0.750885629049327, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06277773435798494, target_position: 0
# []
# Squink_position: 0
# z_score: 0.340081886493263, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4709779340681361, target_position: 0
# []
# Squink_position: 0
# z_score: -0.05741619909631763, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1597845222039522, target_position: 0
# []
# Squink_position: 0
# z_score: -0.08016821137033017, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8949271641453982, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8874740555862441, target_position: 0
# []
# Squink_position: 0
# z_score: -0.46788809057437175, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7609616748768081, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8761295931060809, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7645061597362481, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8721659999205886, target_position: 0
# []
# Squink_position: 0
# z_score: 0.355138682806841, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8704259535181901, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7595485019661969, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4657155820284456, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06297075194132341, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8744565111066804, target_position: 0
# []
# Squink_position: 0
# z_score: 0.34837407847344626, target_position: 0
# []
# Squink_position: 0
# z_score: 0.34083586086793344, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4720217261680241, target_position: 0
# []
# Squink_position: 0
# z_score: 0.33702009432177454, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8856198650898596, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4848587724665681, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7656016028136898, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9464908833124179, target_position: 0
# []
# Squink_position: 0
# z_score: -0.07003851623549034, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8477104681460221, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8042232164279689, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8138931066118855, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06435886038862641, target_position: 0
# []
# Squink_position: 0
# z_score: -0.06435886038862641, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8030496769050287, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9307093503360852, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5019780136915002, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9375821022955287, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3843708811694455, target_position: 0
# []
# Squink_position: 0
# z_score: 1.2574958626703394, target_position: 0
# []
# Squink_position: 0
# z_score: -0.924905132504546, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8310286591674441, target_position: 0
# []
# Squink_position: 0
# z_score: 1.257230547081725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9170946262607507, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9064757290092227, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8434391397080958, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3263398919799745, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3350492870779503e-14, target_position: 0
# []
# Squink_position: 0
# z_score: 0.45515237352842086, target_position: 0
# []
# Squink_position: 0
# z_score: 1.387418169514598, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015231292730348352, target_position: 0
# []
# Squink_position: 0
# z_score: -1.337486931830917, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9423603347984162, target_position: 0
# []
# Squink_position: 0
# z_score: 0.021385222264798793, target_position: 0
# []
# Squink_position: 0
# z_score: 0.006223101042631127, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009340538722494896, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8253406591070092, target_position: 0
# []
# Squink_position: 0
# z_score: 0.030904024867039283, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03719055722585456, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8628153456759438, target_position: 0
# []
# Squink_position: 0
# z_score: 0.02462843793611727, target_position: 0
# []
# Squink_position: 0
# z_score: 0.02462843793611727, target_position: 0
# []
# Squink_position: 0
# z_score: 0.02462843793611727, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03087144871588967, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9455569677363626, target_position: 0
# []
# Squink_position: 0
# z_score: 0.470705323884326, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9488855450175878, target_position: 0
# []
# Squink_position: 0
# z_score: 0.47572508280917275, target_position: 0
# []
# Squink_position: 0
# z_score: 0.47207973105486095, target_position: 0
# []
# Squink_position: 0
# z_score: 0.47621080607130534, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0031763791550086457, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009556290568148822, target_position: 0
# []
# Squink_position: 0
# z_score: -1.8726222833910708, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9341550152215212, target_position: 0
# []
# Squink_position: 0
# z_score: -4.000812389735534, target_position: 10
# A
# [(SQUID_INK, 1997, 10)]
# Squink_position: 10
# z_score: 0.4915253223267379, target_position: 0
# [(SQUID_INK, 1995, -10)]
# Squink_position: 9
# z_score: -1.7276668541038627, target_position: 0
# [(SQUID_INK, 1992, 0)]
# Squink_position: 9
# z_score: 0.9390549800524036, target_position: 0
# [(SQUID_INK, 1993, -9)]
# Squink_position: 0
# z_score: 0.04732069988677888, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39145561748885993, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9487308529606466, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3740493832250311, target_position: 0
# []
# Squink_position: 0
# z_score: 0.047207610182323737, target_position: 0
# []
# Squink_position: 0
# z_score: -1.2766327379407643, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4890223953360324, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04704419690062419, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9306244785317309, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05303747941169225, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8330883553721344, target_position: 0
# []
# Squink_position: 0
# ...
# []
# Squink_position: 0
# z_score: 0.05785395795565654, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5544986983000862, target_position: 0
# []
# Squink_position: 0
# z_score: -0.552219833570132, target_position: 0
# []
# Squink_position: 0
# z_score: -0.23636476540445564, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7044076096061979, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3864413371508433, target_position: 0
# []
# Squink_position: 0
# z_score: -1.7882974316898168, target_position: 0
# []
# Squink_position: 0
# z_score: 0.08707305240225427, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5285115133978501, target_position: 0
# []
# Squink_position: 0
# z_score: 1.340134411608052, target_position: 0
# []
# Squink_position: 0
# z_score: 0.08318533477515827, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07912127138334829, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5439116771342938, target_position: 0
# []
# Squink_position: 0
# z_score: 0.09688081826949368, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7266581702258632, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7262721537020228, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7332569445737089, target_position: 0
# []
# Squink_position: 0
# z_score: -0.545382715765758, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7241902931100166, target_position: 0
# []
# Squink_position: 0
# z_score: -1.174715228756543, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7221197525867945, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0903947933786345, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5347051791591036, target_position: 0
# []
# Squink_position: 0
# z_score: -5.319751940830989, target_position: 23
# A
# [(SQUID_INK, 1998, 23)]
# Squink_position: 23
# z_score: -1.0094691494050425, target_position: 0
# [(SQUID_INK, 1994, 8)]
# Squink_position: 23
# z_score: -0.14677641569129274, target_position: 0
# [(SQUID_INK, 1993, 21)]
# Squink_position: 23
# z_score: 0.14234235797786518, target_position: 0
# [(SQUID_INK, 1993, -23)]
# Squink_position: 0
# z_score: 0.14046169975359257, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7081565706955633, target_position: 0
# []
# Squink_position: 0
# z_score: 0.13850546928603066, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9933871958095891, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7480051790099881, target_position: 0
# []
# Squink_position: 0
# z_score: 0.11690009626158192, target_position: 0
# []
# Squink_position: 0
# z_score: 0.6966475883158518, target_position: 0
# []
# Squink_position: 0
# z_score: -0.20650077386419718, target_position: 0
# []
# Squink_position: 0
# z_score: -0.8238487172619638, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3900831161317733, target_position: 0
# []
# Squink_position: 0
# z_score: 0.38413108461428314, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7027590159815041, target_position: 0
# []
# Squink_position: 0
# z_score: -0.22167344022582963, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3906271258659867, target_position: 0
# []
# Squink_position: 0
# z_score: 1.298264947159443, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5234141245803672, target_position: 0
# []
# Squink_position: 0
# z_score: 0.10282586997248037, target_position: 0
# []
# Squink_position: 0
# z_score: 0.418483849912762, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0306798725160569, target_position: 0
# []
# Squink_position: 0
# z_score: -0.20929630938579266, target_position: 0
# []
# Squink_position: 0
# z_score: 0.1006444838451827, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3300419987027883, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0079307597842329, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5291499870649873, target_position: 0
# []
# Squink_position: 0
# z_score: 0.09203520323562508, target_position: 0
# []
# Squink_position: 0
# z_score: 0.09001245802930487, target_position: 0
# []
# Squink_position: 0
# z_score: 0.1060258431805058, target_position: 0
# []
# Squink_position: 0
# z_score: 0.40895060590798543, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5597291669478544, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0473343630178749, target_position: 0
# []
# Squink_position: 0
# z_score: 0.08529433508174987, target_position: 0
# []
# Squink_position: 0
# z_score: 0.10472245187229104, target_position: 0
# []
# Squink_position: 0
# z_score: 0.09650846970948801, target_position: 0
# []
# Squink_position: 0
# z_score: 0.41938909336753893, target_position: 0
# []
# Squink_position: 0
# z_score: 0.07571290752028437, target_position: 0
# []
# Squink_position: 0
# z_score: -0.2648903265308112, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0671120324357016, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4209006185937939, target_position: 0
# []
# Squink_position: 0
# z_score: 1.753604058350725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.2688144639574042, target_position: 0
# []
# Squink_position: 0
# z_score: 0.06969913505809298, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6075339232338182, target_position: 0
# []
# Squink_position: 0
# z_score: -0.26670941921667923, target_position: 0
# []
# Squink_position: 0
# z_score: 1.0929734128327617, target_position: 0
# []
# Squink_position: 0
# z_score: 1.077644162705846, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3903181408453943, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9596002262177009, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05926183669301827, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6387030161790117, target_position: 0
# []
# Squink_position: 0
# z_score: -1.9902598349689347, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7376195368760765, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05222542183309689, target_position: 0
# []
# Squink_position: 0
# z_score: 1.069553561568983, target_position: 0
# []
# Squink_position: 0
# z_score: -1.0206029156546774, target_position: 0
# []
# Squink_position: 0
# z_score: 0.030237544272473764, target_position: 0
# []
# Squink_position: 0
# z_score: 0.37147875443610073, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3751573861874644, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3730262389018315, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3729322595991222, target_position: 0
# []
# Squink_position: 0
# z_score: 0.030367869262726107, target_position: 0
# []
# Squink_position: 0
# z_score: 0.728825337616711, target_position: 0
# []
# Squink_position: 0
# z_score: -0.31585717337419417, target_position: 0
# []
# Squink_position: 0
# z_score: 0.740592843825282, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0397722934983354, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03515367519364129, target_position: 0
# []
# Squink_position: 0
# z_score: 0.037511296550441275, target_position: 0
# []
# Squink_position: 0
# z_score: 0.73246232242123, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7240471850727969, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6819103504429402, target_position: 0
# []
# Squink_position: 0
# z_score: -0.31983016827554617, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1067506647887158, target_position: 0
# []
# Squink_position: 0
# z_score: 0.037913323107742286, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6713748564291825, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7558725871444342, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03800858519079554, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6684578008641654, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7503381966326409, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04271974194293337, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6609634654021362, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05005266728048306, target_position: 0
# []
# Squink_position: 0
# z_score: 0.763302313096038, target_position: 0
# []
# Squink_position: 0
# z_score: 0.04998420099373455, target_position: 0
# []
# Squink_position: 0
# z_score: -0.30801064017463103, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1119274879859922, target_position: 0
# []
# Squink_position: 0
# z_score: -1.0159261608500534, target_position: 0
# []
# Squink_position: 0
# z_score: -0.30843988115117427, target_position: 0
# []
# Squink_position: 0
# z_score: 0.05717359553883614, target_position: 0
# []
# Squink_position: 0
# z_score: -0.31772704862418827, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7632629231103908, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1320178189093393, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6866647887195685, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4114869346458067, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4113824609124726, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7663075113537564, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03886123424094595, target_position: 0
# []
# Squink_position: 0
# z_score: 0.046330227808693364, target_position: 0
# []
# Squink_position: 0
# z_score: -0.6870779504562531, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7689198223724115, target_position: 0
# []
# Squink_position: 0
# z_score: 0.03178945123149368, target_position: 0
# []
# Squink_position: 0
# z_score: 0.39912940336088315, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4380621997551655, target_position: 0
# []
# Squink_position: 0
# z_score: 0.39252790450581754, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4411611294152724, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7503719892467273, target_position: 0
# []
# Squink_position: 0
# z_score: 0.37265010402268445, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0024672705073940627, target_position: 0
# []
# Squink_position: 0
# z_score: 0.37255714598715944, target_position: 0
# []
# Squink_position: 0
# z_score: -0.009988736939501437, target_position: 0
# []
# Squink_position: 0
# z_score: -0.0025067797260721635, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3677245188570182, target_position: 0
# []
# Squink_position: 0
# z_score: 0.007620462525924412, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7854963607227405, target_position: 0
# []
# Squink_position: 0
# z_score: 0.012829872374307428, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7620628517619906, target_position: 0
# []
# Squink_position: 0
# z_score: 1.175389393428653, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7779287828054646, target_position: 0
# []
# Squink_position: 0
# z_score: 0.010461359799902271, target_position: 0
# []
# Squink_position: 0
# z_score: 0.784752559020512, target_position: 0
# []
# Squink_position: 0
# z_score: 1.5535418834666443, target_position: 0
# []
# Squink_position: 0
# z_score: -1.9201181496913131, target_position: 0
# []
# Squink_position: 0
# z_score: 0.38761339037522147, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3803897132658448, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7815598364655976, target_position: 0
# []
# Squink_position: 0
# z_score: -0.38405035196504517, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3694083610718185e-14, target_position: 0
# []
# Squink_position: 0
# z_score: -0.005213051206473577, target_position: 0
# []
# Squink_position: 0
# z_score: 1.1519862988618095, target_position: 0
# []
# Squink_position: 0
# z_score: -0.39744691854641456, target_position: 0
# []
# Squink_position: 0
# z_score: -0.005199838870753432, target_position: 0
# []
# Squink_position: 0
# z_score: -0.02121352712205121, target_position: 0
# []
# Squink_position: 0
# z_score: -3.078474432761004, target_position: 0
# A
# [(SQUID_INK, 2006, 0)]
# Squink_position: 0
# z_score: 1.5157640582244123, target_position: 0
# []
# Squink_position: 0
# z_score: -0.76981926997896, target_position: 0
# []
# Squink_position: 0
# z_score: 0.38220244537086406, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1443617796188588, target_position: 0
# []
# Squink_position: 0
# z_score: 2.2478638238877653, target_position: 0
# []
# Squink_position: 0
# z_score: -0.015086334388519805, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4995302053194075, target_position: 0
# []
# Squink_position: 0
# z_score: -0.3681474350573742, target_position: 0
# []
# Squink_position: 0
# z_score: -1.1050752284109218, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015022230366466941, target_position: 0
# []
# Squink_position: 0
# z_score: -1.098071886962734, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8717917205400205, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009964180400014018, target_position: 0
# []
# Squink_position: 0
# z_score: -0.7315963926274488, target_position: 0
# []
# Squink_position: 0
# z_score: 0.7514159876799503, target_position: 0
# []
# Squink_position: 0
# z_score: -2.721602439272462, target_position: 0
# []
# Squink_position: 0
# z_score: 1.2983858696125954, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5049734137861491, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3933282965427728, target_position: 0
# []
# Squink_position: 0
# z_score: 0.3900169051068991, target_position: 0
# []
# Squink_position: 0
# z_score: -0.5021036128591856, target_position: 0
# []
# Squink_position: 0
# z_score: -0.051215697988241694, target_position: 0
# []
# Squink_position: 0
# z_score: 0.407852148320884, target_position: 0
# []
# Squink_position: 0
# z_score: -1.4056180128030173, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9438955732841919, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3101909305568444, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9385424309083068, target_position: 0
# []
# Squink_position: 0
# z_score: 0.40114566124410395, target_position: 0
# []
# Squink_position: 0
# z_score: -0.49773620034635835, target_position: 0
# []
# Squink_position: 0
# z_score: -0.042327373583177216, target_position: 0
# []
# Squink_position: 0
# z_score: -0.03636361731341435, target_position: 0
# []
# Squink_position: 0
# z_score: -0.03943085460797698, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4147566096610725, target_position: 0
# []
# Squink_position: 0
# z_score: -0.48326298593559686, target_position: 0
# []
# Squink_position: 0
# z_score: 0.8810235875623802, target_position: 0
# []
# Squink_position: 0
# z_score: -0.036757133187242955, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4893642480204163, target_position: 0
# []
# Squink_position: 0
# z_score: -0.021562118653268885, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3433370572442382, target_position: 0
# []
# Squink_position: 0
# z_score: -0.033694420419933736, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9408454588299057, target_position: 0
# []
# Squink_position: 0
# z_score: -0.46861759983727047, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4541216188758901, target_position: 0
# []
# Squink_position: 0
# z_score: -0.012446476708395035, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3939264929906718, target_position: 0
# []
# Squink_position: 0
# z_score: -1.3767878654014467, target_position: 0
# []
# Squink_position: 0
# z_score: 0.009226364455801309, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4563628591794644, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9072737364326092, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4827108810820611, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01855019338072233, target_position: 0
# []
# Squink_position: 0
# z_score: 0.01855019338072233, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4825891066204158, target_position: 0
# []
# Squink_position: 0
# z_score: -0.4421127359776696, target_position: 0
# []
# Squink_position: 0
# z_score: 1.8402361223335963, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9021225080450191, target_position: 0
# []
# Squink_position: 0
# z_score: 0.015244113753006145, target_position: 0
# []
# Squink_position: 0
# z_score: 0.953650997508781, target_position: 0
# []
# Squink_position: 0
# z_score: -0.43965000981438607, target_position: 0
# []
# Squink_position: 0
# z_score: 1.3989620627613584, target_position: 0
# []
# Squink_position: 0
# z_score: -0.9069154273348621, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9263520679044304, target_position: 0
# []
# Squink_position: 0
# z_score: 0.4749225181889964, target_position: 0
# []
# Squink_position: 0
# z_score: 0.0217099934947598, target_position: 0
# []
# Squink_position: 0
# z_score: 0.9474836571370099, target_position: 0
# []
# {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': -1090.0}

# %%
import matplotlib.pyplot as plt    
product = "SQUID_INK"

resin_metrics = bt.calculate_metrics(product)
print(f"PNL: {bt.pnl}")

print(f"Midpoint Sharpe: {resin_metrics['midpoint_sharpe']:.4f}")
print(f"Spreadcrossing Sharpe: {resin_metrics['spreadcrossing_sharpe']:.4f}")
print(f"Midpoint PnL (bps): {resin_metrics['midpoint_pnl_bps']:.2f}")
print(f"Spreadcrossing PnL (bps): {resin_metrics['spreadcrossing_pnl_bps']:.2f}")

# THIS PART PLOTS SPREADCROSSING_PNL AND MIDPOINT_PNL
spreadcrossing_pnl_history = bt.get_metric("spreadcrossing_pnl", product)
midpoint_pnl_history = bt.get_metric("midpoint_pnl", product)
timestamps = np.unique(bt.market_data["timestamp"])

plt.plot(timestamps, spreadcrossing_pnl_history, label="Spreadcrossing PnL", color="blue")
plt.plot(timestamps, midpoint_pnl_history, label="Midpoint PnL", color="orange")
plt.xlabel("Timestamp")
plt.ylabel("PnL")
plt.title("Spread Crossing vs Midpoint PnL Over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# PNL: {'KELP': 0.0, 'RAINFOREST_RESIN': 0, 'SQUID_INK': -1090.0}
# Midpoint Sharpe: -0.6035
# Spreadcrossing Sharpe: -0.4622
# Midpoint PnL (bps): -0.08
# Spreadcrossing PnL (bps): -0.08

# %% [markdown]
# You can copy paste everything, except for the Trader algo, which should be whatever algo you wish to backtest.
